# %% [markdown]
# # Example 02: General Use of XGBoostClassifierHyperOpt
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/slickml/slick-ml/blob/master/examples/optimization/example_02_XGBoostClassifierHyperOpt.ipynb)

# %% [markdown]
# ### Google Colab Configuration

# %%
# !git clone https://github.com/slickml/slick-ml.git
# %cd slick-ml
# !pip install -r requirements.txt

# %% [markdown]
# ### Local Environment Configuration

# %%
# # Change path to project root
# %cd ../..
# Out:
# /home/amirhessam/Documents/GitHub/slick-ml

# %% [markdown]
# ### Import Python Libraries

# %%
# %load_ext autoreload

# widen the screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

# change the path and loading class
import os, sys
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# %autoreload
from slickml.optimization import XGBoostClassifierHyperOpt
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ----
# # XGBoostClassifierHyperOpt Docstring

# %%
# loading data
df = pd.read_csv("data/clf_data.csv")
df.head()
# Out:
#     F1   F2   F3    F4      F5      F6  CLASS
# 0  5.7  4.7  3.7  58.0  249.30  456.47      0
# 1  7.7  6.6  4.1  20.0  260.92  443.43      1
# 2  6.2  4.3  4.6  59.0  255.63  478.96      1
# 3  5.7  4.4  3.8  49.0  195.28  381.94      0
# 4  9.1  4.7  4.6  17.0  259.55  395.67      1

# %%
# define X, y
y = df.CLASS.values
X = df.drop(["CLASS"], axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    stratify=y,
                                                    random_state=1367)

# %%
from hyperopt import hp
def get_xgb_params():
    """ Define Parameter Space"""
    params = {
        "nthread": 4,
        "booster": "gbtree",
        "tree_method": "hist",
        "objective": "binary:logistic",
        "max_depth": hp.choice("max_depth", range(5, 100, 5)),
        "learning_rate": hp.quniform("learning_rate", 0.01, 0.50, 0.01),
        "gamma": hp.quniform("gamma", 0, 0.50, 0.01),
        "min_child_weight": hp.quniform("min_child_weight", 1, 10, 1),
        "subsample": hp.quniform("subsample", 0.1, 1, 0.01),
        "colsample_bytree": hp.quniform("colsample_bytree", 0.1, 1.0, 0.01),
        "gamma": hp.quniform("gamma", 0.0, 1.0, 0.01),
        "reg_alpha": hp.quniform("reg_alpha", 0.0, 1.0, 0.01),
        "reg_lambda": hp.quniform("reg_lambda", 0.0, 1.0, 0.01),
    }
    
    return params

# %%
XGBoostClassifierHyperOpt()

# %%
# %autoreload
from slickml.classification import XGBoostClassifier
# from slickml.optimization import XGBoostClassifierHyperOpt

xho = XGBoostClassifierHyperOpt(num_boost_round=200,
                                metrics="logloss",
                                n_splits=3,
                                shuffle=True,
                                early_stopping_rounds=20,
                                func_name="xgb_cv",
                                space=get_xgb_params(),
                                max_evals=100,
                                verbose=False
                               )

xho.fit(X_train,y_train)
# Out:
# 100%|██████████| 100/100 [00:12<00:00,  7.80trial/s, best loss: 0.13210466666666668]

# %% [markdown]
# ### Best set of parameters from all runs

# %%
xho.get_optimization_results()
# Out:
#    colsample_bytree  gamma  learning_rate  max_depth  min_child_weight  \
# 0              0.83   0.65           0.34         10               3.0
#
#    reg_alpha  reg_lambda  subsample
# 0       0.96        0.43        0.9

# %% [markdown]
# ### Results from each trial

# %%
import pprint
pprint.pprint(xho.get_optimization_trials().trials)
# Out:
# [{'book_time': datetime.datetime(2021, 5, 31, 21, 17, 50, 555000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [0],
#                     'gamma': [0],
#                     'learning_rate': [0],
#                     'max_depth': [0],
#                     'min_child_weight': [0],
#                     'reg_alpha': [0],
#                     'reg_lambda': [0],
#                     'subsample': [0]},
#            'tid': 0,
#            'vals': {'colsample_bytree': [0.5700000000000001],
#                     'gamma': [0.6900000000000001],
#                     'learning_rate': [0.19],
#                     'max_depth': [10],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [1.0],
#                     'reg_lambda': [0.9500000000000001],
#                     'subsample': [0.67]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 50, 704000),
#   'result': {'loss': 0.361508, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 0,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 50, 711000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [1],
#                     'gamma': [1],
#                     'learning_rate': [1],
#                     'max_depth': [1],
#                     'min_child_weight': [1],
#                     'reg_alpha': [1],
#                     'reg_lambda': [1],
#                     'subsample': [1]},
#            'tid': 1,
#            'vals': {'colsample_bytree': [0.71],
#                     'gamma': [0.8200000000000001],
#                     'learning_rate': [0.21],
#                     'max_depth': [17],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.23],
#                     'reg_lambda': [0.41000000000000003],
#                     'subsample': [0.11]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 50, 763000),
#   'result': {'loss': 0.29229299999999997, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 1,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 50, 769000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [2],
#                     'gamma': [2],
#                     'learning_rate': [2],
#                     'max_depth': [2],
#                     'min_child_weight': [2],
#                     'reg_alpha': [2],
#                     'reg_lambda': [2],
#                     'subsample': [2]},
#            'tid': 2,
#            'vals': {'colsample_bytree': [0.13],
#                     'gamma': [0.87],
#                     'learning_rate': [0.46],
#                     'max_depth': [13],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.8],
#                     'reg_lambda': [0.39],
#                     'subsample': [0.73]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 50, 930000),
#   'result': {'loss': 0.2860243333333334, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 2,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 50, 937000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [3],
#                     'gamma': [3],
#                     'learning_rate': [3],
#                     'max_depth': [3],
#                     'min_child_weight': [3],
#                     'reg_alpha': [3],
#                     'reg_lambda': [3],
#                     'subsample': [3]},
#            'tid': 3,
#            'vals': {'colsample_bytree': [0.38],
#                     'gamma': [0.19],
#                     'learning_rate': [0.33],
#                     'max_depth': [13],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.35000000000000003],
#                     'reg_lambda': [0.3],
#                     'subsample': [0.12]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 83000),
#   'result': {'loss': 0.27520100000000003, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 3,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 90000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [4],
#                     'gamma': [4],
#                     'learning_rate': [4],
#                     'max_depth': [4],
#                     'min_child_weight': [4],
#                     'reg_alpha': [4],
#                     'reg_lambda': [4],
#                     'subsample': [4]},
#            'tid': 4,
#            'vals': {'colsample_bytree': [0.8300000000000001],
#                     'gamma': [0.91],
#                     'learning_rate': [0.42],
#                     'max_depth': [10],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.8],
#                     'reg_lambda': [0.22],
#                     'subsample': [0.93]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 144000),
#   'result': {'loss': 0.15325733333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 4,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 150000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [5],
#                     'gamma': [5],
#                     'learning_rate': [5],
#                     'max_depth': [5],
#                     'min_child_weight': [5],
#                     'reg_alpha': [5],
#                     'reg_lambda': [5],
#                     'subsample': [5]},
#            'tid': 5,
#            'vals': {'colsample_bytree': [0.49],
#                     'gamma': [0.71],
#                     'learning_rate': [0.29],
#                     'max_depth': [5],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.89],
#                     'reg_lambda': [0.78],
#                     'subsample': [0.48]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 195000),
#   'result': {'loss': 0.30951733333333337, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 5,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 202000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [6],
#                     'gamma': [6],
#                     'learning_rate': [6],
#                     'max_depth': [6],
#                     'min_child_weight': [6],
#                     'reg_alpha': [6],
#                     'reg_lambda': [6],
#                     'subsample': [6]},
#            'tid': 6,
#            'vals': {'colsample_bytree': [0.73],
#                     'gamma': [0.11],
#                     'learning_rate': [0.06],
#                     'max_depth': [0],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.17],
#                     'reg_lambda': [0.43],
#                     'subsample': [0.13]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 275000),
#   'result': {'loss': 0.3579046666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 6,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 281000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [7],
#                     'gamma': [7],
#                     'learning_rate': [7],
#                     'max_depth': [7],
#                     'min_child_weight': [7],
#                     'reg_alpha': [7],
#                     'reg_lambda': [7],
#                     'subsample': [7]},
#            'tid': 7,
#            'vals': {'colsample_bytree': [0.92],
#                     'gamma': [0.17],
#                     'learning_rate': [0.35000000000000003],
#                     'max_depth': [6],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.18],
#                     'reg_lambda': [0.2],
#                     'subsample': [0.42]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 311000),
#   'result': {'loss': 0.348567, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 7,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 317000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [8],
#                     'gamma': [8],
#                     'learning_rate': [8],
#                     'max_depth': [8],
#                     'min_child_weight': [8],
#                     'reg_alpha': [8],
#                     'reg_lambda': [8],
#                     'subsample': [8]},
#            'tid': 8,
#            'vals': {'colsample_bytree': [1.0],
#                     'gamma': [0.79],
#                     'learning_rate': [0.32],
#                     'max_depth': [17],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.3],
#                     'reg_lambda': [0.43],
#                     'subsample': [0.96]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 359000),
#   'result': {'loss': 0.3102796666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 8,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 364000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [9],
#                     'gamma': [9],
#                     'learning_rate': [9],
#                     'max_depth': [9],
#                     'min_child_weight': [9],
#                     'reg_alpha': [9],
#                     'reg_lambda': [9],
#                     'subsample': [9]},
#            'tid': 9,
#            'vals': {'colsample_bytree': [0.54],
#                     'gamma': [0.2],
#                     'learning_rate': [0.07],
#                     'max_depth': [3],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.8200000000000001],
#                     'reg_lambda': [0.6900000000000001],
#                     'subsample': [0.9400000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 408000),
#   'result': {'loss': 0.35209533333333337, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 9,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 413000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [10],
#                     'gamma': [10],
#                     'learning_rate': [10],
#                     'max_depth': [10],
#                     'min_child_weight': [10],
#                     'reg_alpha': [10],
#                     'reg_lambda': [10],
#                     'subsample': [10]},
#            'tid': 10,
#            'vals': {'colsample_bytree': [0.99],
#                     'gamma': [0.14],
#                     'learning_rate': [0.15],
#                     'max_depth': [7],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.31],
#                     'reg_lambda': [0.4],
#                     'subsample': [0.63]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 471000),
#   'result': {'loss': 0.21795033333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 10,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 477000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [11],
#                     'gamma': [11],
#                     'learning_rate': [11],
#                     'max_depth': [11],
#                     'min_child_weight': [11],
#                     'reg_alpha': [11],
#                     'reg_lambda': [11],
#                     'subsample': [11]},
#            'tid': 11,
#            'vals': {'colsample_bytree': [0.98],
#                     'gamma': [0.51],
#                     'learning_rate': [0.46],
#                     'max_depth': [15],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.79],
#                     'reg_lambda': [0.02],
#                     'subsample': [0.54]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 549000),
#   'result': {'loss': 0.34780966666666674, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 11,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 554000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [12],
#                     'gamma': [12],
#                     'learning_rate': [12],
#                     'max_depth': [12],
#                     'min_child_weight': [12],
#                     'reg_alpha': [12],
#                     'reg_lambda': [12],
#                     'subsample': [12]},
#            'tid': 12,
#            'vals': {'colsample_bytree': [0.15],
#                     'gamma': [0.85],
#                     'learning_rate': [0.3],
#                     'max_depth': [18],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.14],
#                     'reg_lambda': [0.67],
#                     'subsample': [0.4]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 619000),
#   'result': {'loss': 0.2924543333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 12,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 626000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [13],
#                     'gamma': [13],
#                     'learning_rate': [13],
#                     'max_depth': [13],
#                     'min_child_weight': [13],
#                     'reg_alpha': [13],
#                     'reg_lambda': [13],
#                     'subsample': [13]},
#            'tid': 13,
#            'vals': {'colsample_bytree': [0.37],
#                     'gamma': [0.06],
#                     'learning_rate': [0.23],
#                     'max_depth': [6],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.45],
#                     'reg_lambda': [0.86],
#                     'subsample': [0.2]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 836000),
#   'result': {'loss': 0.18645166666666668, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 13,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 843000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [14],
#                     'gamma': [14],
#                     'learning_rate': [14],
#                     'max_depth': [14],
#                     'min_child_weight': [14],
#                     'reg_alpha': [14],
#                     'reg_lambda': [14],
#                     'subsample': [14]},
#            'tid': 14,
#            'vals': {'colsample_bytree': [0.64],
#                     'gamma': [0.38],
#                     'learning_rate': [0.09],
#                     'max_depth': [12],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.17],
#                     'reg_lambda': [0.88],
#                     'subsample': [0.28]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 948000),
#   'result': {'loss': 0.1985583333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 14,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 955000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [15],
#                     'gamma': [15],
#                     'learning_rate': [15],
#                     'max_depth': [15],
#                     'min_child_weight': [15],
#                     'reg_alpha': [15],
#                     'reg_lambda': [15],
#                     'subsample': [15]},
#            'tid': 15,
#            'vals': {'colsample_bytree': [0.52],
#                     'gamma': [0.55],
#                     'learning_rate': [0.48],
#                     'max_depth': [14],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.23],
#                     'reg_lambda': [0.24],
#                     'subsample': [0.6900000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 990000),
#   'result': {'loss': 0.4010606666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 15,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 51, 996000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [16],
#                     'gamma': [16],
#                     'learning_rate': [16],
#                     'max_depth': [16],
#                     'min_child_weight': [16],
#                     'reg_alpha': [16],
#                     'reg_lambda': [16],
#                     'subsample': [16]},
#            'tid': 16,
#            'vals': {'colsample_bytree': [0.38],
#                     'gamma': [0.49],
#                     'learning_rate': [0.03],
#                     'max_depth': [13],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.25],
#                     'reg_lambda': [0.12],
#                     'subsample': [0.39]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 44000),
#   'result': {'loss': 0.24961600000000003, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 16,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 50000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [17],
#                     'gamma': [17],
#                     'learning_rate': [17],
#                     'max_depth': [17],
#                     'min_child_weight': [17],
#                     'reg_alpha': [17],
#                     'reg_lambda': [17],
#                     'subsample': [17]},
#            'tid': 17,
#            'vals': {'colsample_bytree': [0.28],
#                     'gamma': [0.68],
#                     'learning_rate': [0.22],
#                     'max_depth': [10],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.76],
#                     'reg_lambda': [0.79],
#                     'subsample': [0.61]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 110000),
#   'result': {'loss': 0.2789566666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 17,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 117000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [18],
#                     'gamma': [18],
#                     'learning_rate': [18],
#                     'max_depth': [18],
#                     'min_child_weight': [18],
#                     'reg_alpha': [18],
#                     'reg_lambda': [18],
#                     'subsample': [18]},
#            'tid': 18,
#            'vals': {'colsample_bytree': [0.65],
#                     'gamma': [0.22],
#                     'learning_rate': [0.47000000000000003],
#                     'max_depth': [11],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.67],
#                     'reg_lambda': [0.11],
#                     'subsample': [0.88]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 172000),
#   'result': {'loss': 0.19552999999999998, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 18,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 177000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [19],
#                     'gamma': [19],
#                     'learning_rate': [19],
#                     'max_depth': [19],
#                     'min_child_weight': [19],
#                     'reg_alpha': [19],
#                     'reg_lambda': [19],
#                     'subsample': [19]},
#            'tid': 19,
#            'vals': {'colsample_bytree': [0.76],
#                     'gamma': [0.35000000000000003],
#                     'learning_rate': [0.16],
#                     'max_depth': [5],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.93],
#                     'reg_lambda': [0.59],
#                     'subsample': [0.13]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 236000),
#   'result': {'loss': 0.26135933333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 19,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 279000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [20],
#                     'gamma': [20],
#                     'learning_rate': [20],
#                     'max_depth': [20],
#                     'min_child_weight': [20],
#                     'reg_alpha': [20],
#                     'reg_lambda': [20],
#                     'subsample': [20]},
#            'tid': 20,
#            'vals': {'colsample_bytree': [0.9],
#                     'gamma': [1.0],
#                     'learning_rate': [0.39],
#                     'max_depth': [4],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.53],
#                     'reg_lambda': [0.54],
#                     'subsample': [0.8200000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 332000),
#   'result': {'loss': 0.3462096666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 20,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 369000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [21],
#                     'gamma': [21],
#                     'learning_rate': [21],
#                     'max_depth': [21],
#                     'min_child_weight': [21],
#                     'reg_alpha': [21],
#                     'reg_lambda': [21],
#                     'subsample': [21]},
#            'tid': 21,
#            'vals': {'colsample_bytree': [0.23],
#                     'gamma': [0.97],
#                     'learning_rate': [0.39],
#                     'max_depth': [9],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.02],
#                     'reg_lambda': [0.99],
#                     'subsample': [0.24]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 416000),
#   'result': {'loss': 0.301612, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 21,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 460000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [22],
#                     'gamma': [22],
#                     'learning_rate': [22],
#                     'max_depth': [22],
#                     'min_child_weight': [22],
#                     'reg_alpha': [22],
#                     'reg_lambda': [22],
#                     'subsample': [22]},
#            'tid': 22,
#            'vals': {'colsample_bytree': [0.8300000000000001],
#                     'gamma': [0.0],
#                     'learning_rate': [0.26],
#                     'max_depth': [6],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.48],
#                     'reg_lambda': [0.03],
#                     'subsample': [0.25]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 487000),
#   'result': {'loss': 0.4688116666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 22,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 526000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [23],
#                     'gamma': [23],
#                     'learning_rate': [23],
#                     'max_depth': [23],
#                     'min_child_weight': [23],
#                     'reg_alpha': [23],
#                     'reg_lambda': [23],
#                     'subsample': [23]},
#            'tid': 23,
#            'vals': {'colsample_bytree': [0.4],
#                     'gamma': [0.01],
#                     'learning_rate': [0.4],
#                     'max_depth': [8],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.59],
#                     'reg_lambda': [0.28],
#                     'subsample': [0.78]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 656000),
#   'result': {'loss': 0.25433633333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 23,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 701000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [24],
#                     'gamma': [24],
#                     'learning_rate': [24],
#                     'max_depth': [24],
#                     'min_child_weight': [24],
#                     'reg_alpha': [24],
#                     'reg_lambda': [24],
#                     'subsample': [24]},
#            'tid': 24,
#            'vals': {'colsample_bytree': [0.28],
#                     'gamma': [0.35000000000000003],
#                     'learning_rate': [0.25],
#                     'max_depth': [1],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.41000000000000003],
#                     'reg_lambda': [0.89],
#                     'subsample': [0.31]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 741000),
#   'result': {'loss': 0.19304433333333335, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 24,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 779000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [25],
#                     'gamma': [25],
#                     'learning_rate': [25],
#                     'max_depth': [25],
#                     'min_child_weight': [25],
#                     'reg_alpha': [25],
#                     'reg_lambda': [25],
#                     'subsample': [25]},
#            'tid': 25,
#            'vals': {'colsample_bytree': [0.45],
#                     'gamma': [0.6],
#                     'learning_rate': [0.13],
#                     'max_depth': [2],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.64],
#                     'reg_lambda': [0.16],
#                     'subsample': [0.54]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 836000),
#   'result': {'loss': 0.21315133333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 25,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 882000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [26],
#                     'gamma': [26],
#                     'learning_rate': [26],
#                     'max_depth': [26],
#                     'min_child_weight': [26],
#                     'reg_alpha': [26],
#                     'reg_lambda': [26],
#                     'subsample': [26]},
#            'tid': 26,
#            'vals': {'colsample_bytree': [0.64],
#                     'gamma': [0.9400000000000001],
#                     'learning_rate': [0.43],
#                     'max_depth': [10],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.44],
#                     'reg_lambda': [0.53],
#                     'subsample': [0.19]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 929000),
#   'result': {'loss': 0.3150583333333334, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 26,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 52, 969000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [27],
#                     'gamma': [27],
#                     'learning_rate': [27],
#                     'max_depth': [27],
#                     'min_child_weight': [27],
#                     'reg_alpha': [27],
#                     'reg_lambda': [27],
#                     'subsample': [27]},
#            'tid': 27,
#            'vals': {'colsample_bytree': [0.29],
#                     'gamma': [0.43],
#                     'learning_rate': [0.27],
#                     'max_depth': [6],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.7000000000000001],
#                     'reg_lambda': [0.63],
#                     'subsample': [1.0]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 22000),
#   'result': {'loss': 0.34359500000000004, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 27,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 70000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [28],
#                     'gamma': [28],
#                     'learning_rate': [28],
#                     'max_depth': [28],
#                     'min_child_weight': [28],
#                     'reg_alpha': [28],
#                     'reg_lambda': [28],
#                     'subsample': [28]},
#            'tid': 28,
#            'vals': {'colsample_bytree': [0.8],
#                     'gamma': [0.28],
#                     'learning_rate': [0.19],
#                     'max_depth': [16],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.56],
#                     'reg_lambda': [0.74],
#                     'subsample': [0.35000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 176000),
#   'result': {'loss': 0.37975766666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 28,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 218000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [29],
#                     'gamma': [29],
#                     'learning_rate': [29],
#                     'max_depth': [29],
#                     'min_child_weight': [29],
#                     'reg_alpha': [29],
#                     'reg_lambda': [29],
#                     'subsample': [29]},
#            'tid': 29,
#            'vals': {'colsample_bytree': [0.59],
#                     'gamma': [0.08],
#                     'learning_rate': [0.36],
#                     'max_depth': [10],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.97],
#                     'reg_lambda': [0.33],
#                     'subsample': [0.47000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 280000),
#   'result': {'loss': 0.37030499999999994, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 29,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 328000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [30],
#                     'gamma': [30],
#                     'learning_rate': [30],
#                     'max_depth': [30],
#                     'min_child_weight': [30],
#                     'reg_alpha': [30],
#                     'reg_lambda': [30],
#                     'subsample': [30]},
#            'tid': 30,
#            'vals': {'colsample_bytree': [0.45],
#                     'gamma': [0.64],
#                     'learning_rate': [0.23],
#                     'max_depth': [12],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.05],
#                     'reg_lambda': [0.89],
#                     'subsample': [0.86]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 426000),
#   'result': {'loss': 0.40015399999999995, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 30,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 469000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [31],
#                     'gamma': [31],
#                     'learning_rate': [31],
#                     'max_depth': [31],
#                     'min_child_weight': [31],
#                     'reg_alpha': [31],
#                     'reg_lambda': [31],
#                     'subsample': [31]},
#            'tid': 31,
#            'vals': {'colsample_bytree': [0.19],
#                     'gamma': [0.91],
#                     'learning_rate': [0.2],
#                     'max_depth': [6],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.38],
#                     'reg_lambda': [0.49],
#                     'subsample': [0.73]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 537000),
#   'result': {'loss': 0.2610476666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 31,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 585000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [32],
#                     'gamma': [32],
#                     'learning_rate': [32],
#                     'max_depth': [32],
#                     'min_child_weight': [32],
#                     'reg_alpha': [32],
#                     'reg_lambda': [32],
#                     'subsample': [32]},
#            'tid': 32,
#            'vals': {'colsample_bytree': [0.32],
#                     'gamma': [0.75],
#                     'learning_rate': [0.43],
#                     'max_depth': [16],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.61],
#                     'reg_lambda': [0.09],
#                     'subsample': [0.18]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 612000),
#   'result': {'loss': 0.468588, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 32,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 655000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [33],
#                     'gamma': [33],
#                     'learning_rate': [33],
#                     'max_depth': [33],
#                     'min_child_weight': [33],
#                     'reg_alpha': [33],
#                     'reg_lambda': [33],
#                     'subsample': [33]},
#            'tid': 33,
#            'vals': {'colsample_bytree': [0.87],
#                     'gamma': [0.26],
#                     'learning_rate': [0.17],
#                     'max_depth': [4],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.87],
#                     'reg_lambda': [1.0],
#                     'subsample': [0.61]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 729000),
#   'result': {'loss': 0.2906836666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 33,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 780000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [34],
#                     'gamma': [34],
#                     'learning_rate': [34],
#                     'max_depth': [34],
#                     'min_child_weight': [34],
#                     'reg_alpha': [34],
#                     'reg_lambda': [34],
#                     'subsample': [34]},
#            'tid': 34,
#            'vals': {'colsample_bytree': [0.61],
#                     'gamma': [0.05],
#                     'learning_rate': [0.5],
#                     'max_depth': [11],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.72],
#                     'reg_lambda': [0.8300000000000001],
#                     'subsample': [0.5]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 808000),
#   'result': {'loss': 0.47661166666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 34,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 853000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [35],
#                     'gamma': [35],
#                     'learning_rate': [35],
#                     'max_depth': [35],
#                     'min_child_weight': [35],
#                     'reg_alpha': [35],
#                     'reg_lambda': [35],
#                     'subsample': [35]},
#            'tid': 35,
#            'vals': {'colsample_bytree': [0.71],
#                     'gamma': [0.8],
#                     'learning_rate': [0.11],
#                     'max_depth': [0],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.5],
#                     'reg_lambda': [0.34],
#                     'subsample': [1.0]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 901000),
#   'result': {'loss': 0.206637, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 35,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 53, 951000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [36],
#                     'gamma': [36],
#                     'learning_rate': [36],
#                     'max_depth': [36],
#                     'min_child_weight': [36],
#                     'reg_alpha': [36],
#                     'reg_lambda': [36],
#                     'subsample': [36]},
#            'tid': 36,
#            'vals': {'colsample_bytree': [0.48],
#                     'gamma': [0.71],
#                     'learning_rate': [0.29],
#                     'max_depth': [14],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [1.0],
#                     'reg_lambda': [0.22],
#                     'subsample': [0.92]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 20000),
#   'result': {'loss': 0.292866, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 36,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 66000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [37],
#                     'gamma': [37],
#                     'learning_rate': [37],
#                     'max_depth': [37],
#                     'min_child_weight': [37],
#                     'reg_alpha': [37],
#                     'reg_lambda': [37],
#                     'subsample': [37]},
#            'tid': 37,
#            'vals': {'colsample_bytree': [0.12],
#                     'gamma': [0.43],
#                     'learning_rate': [0.35000000000000003],
#                     'max_depth': [3],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.86],
#                     'reg_lambda': [0.46],
#                     'subsample': [0.77]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 121000),
#   'result': {'loss': 0.3243236666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 37,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 173000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [38],
#                     'gamma': [38],
#                     'learning_rate': [38],
#                     'max_depth': [38],
#                     'min_child_weight': [38],
#                     'reg_alpha': [38],
#                     'reg_lambda': [38],
#                     'subsample': [38]},
#            'tid': 38,
#            'vals': {'colsample_bytree': [0.79],
#                     'gamma': [0.59],
#                     'learning_rate': [0.33],
#                     'max_depth': [2],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.33],
#                     'reg_lambda': [0.36],
#                     'subsample': [0.18]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 235000),
#   'result': {'loss': 0.3705216666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 38,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 286000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [39],
#                     'gamma': [39],
#                     'learning_rate': [39],
#                     'max_depth': [39],
#                     'min_child_weight': [39],
#                     'reg_alpha': [39],
#                     'reg_lambda': [39],
#                     'subsample': [39]},
#            'tid': 39,
#            'vals': {'colsample_bytree': [0.71],
#                     'gamma': [0.29],
#                     'learning_rate': [0.24],
#                     'max_depth': [7],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.47000000000000003],
#                     'reg_lambda': [0.9500000000000001],
#                     'subsample': [0.67]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 435000),
#   'result': {'loss': 0.25109166666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 39,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 486000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [40],
#                     'gamma': [40],
#                     'learning_rate': [40],
#                     'max_depth': [40],
#                     'min_child_weight': [40],
#                     'reg_alpha': [40],
#                     'reg_lambda': [40],
#                     'subsample': [40]},
#            'tid': 40,
#            'vals': {'colsample_bytree': [0.54],
#                     'gamma': [0.9],
#                     'learning_rate': [0.28],
#                     'max_depth': [17],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.11],
#                     'reg_lambda': [0.27],
#                     'subsample': [0.45]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 541000),
#   'result': {'loss': 0.3242146666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 40,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 592000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [41],
#                     'gamma': [41],
#                     'learning_rate': [41],
#                     'max_depth': [41],
#                     'min_child_weight': [41],
#                     'reg_alpha': [41],
#                     'reg_lambda': [41],
#                     'subsample': [41]},
#            'tid': 41,
#            'vals': {'colsample_bytree': [0.34],
#                     'gamma': [0.48],
#                     'learning_rate': [0.01],
#                     'max_depth': [15],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.74],
#                     'reg_lambda': [0.73],
#                     'subsample': [0.58]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 641000),
#   'result': {'loss': 0.268497, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 41,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 689000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [42],
#                     'gamma': [42],
#                     'learning_rate': [42],
#                     'max_depth': [42],
#                     'min_child_weight': [42],
#                     'reg_alpha': [42],
#                     'reg_lambda': [42],
#                     'subsample': [42]},
#            'tid': 42,
#            'vals': {'colsample_bytree': [0.93],
#                     'gamma': [0.76],
#                     'learning_rate': [0.32],
#                     'max_depth': [18],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.39],
#                     'reg_lambda': [0.59],
#                     'subsample': [0.1]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 751000),
#   'result': {'loss': 0.2871876666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 42,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 806000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [43],
#                     'gamma': [43],
#                     'learning_rate': [43],
#                     'max_depth': [43],
#                     'min_child_weight': [43],
#                     'reg_alpha': [43],
#                     'reg_lambda': [43],
#                     'subsample': [43]},
#            'tid': 43,
#            'vals': {'colsample_bytree': [0.68],
#                     'gamma': [0.64],
#                     'learning_rate': [0.18],
#                     'max_depth': [1],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.8300000000000001],
#                     'reg_lambda': [0.18],
#                     'subsample': [0.35000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 938000),
#   'result': {'loss': 0.2820703333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 43,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 17, 54, 992000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [44],
#                     'gamma': [44],
#                     'learning_rate': [44],
#                     'max_depth': [44],
#                     'min_child_weight': [44],
#                     'reg_alpha': [44],
#                     'reg_lambda': [44],
#                     'subsample': [44]},
#            'tid': 44,
#            'vals': {'colsample_bytree': [0.41000000000000003],
#                     'gamma': [0.12],
#                     'learning_rate': [0.43],
#                     'max_depth': [8],
# ...
#            'idxs': {'colsample_bytree': [85],
#                     'gamma': [85],
#                     'learning_rate': [85],
#                     'max_depth': [85],
#                     'min_child_weight': [85],
#                     'reg_alpha': [85],
#                     'reg_lambda': [85],
#                     'subsample': [85]},
#            'tid': 85,
#            'vals': {'colsample_bytree': [0.7000000000000001],
#                     'gamma': [0.88],
#                     'learning_rate': [0.4],
#                     'max_depth': [11],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.53],
#                     'reg_lambda': [0.8],
#                     'subsample': [0.44]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 133000),
#   'result': {'loss': 0.476041, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 85,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 200000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [86],
#                     'gamma': [86],
#                     'learning_rate': [86],
#                     'max_depth': [86],
#                     'min_child_weight': [86],
#                     'reg_alpha': [86],
#                     'reg_lambda': [86],
#                     'subsample': [86]},
#            'tid': 86,
#            'vals': {'colsample_bytree': [0.59],
#                     'gamma': [0.51],
#                     'learning_rate': [0.36],
#                     'max_depth': [18],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.81],
#                     'reg_lambda': [0.52],
#                     'subsample': [0.72]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 301000),
#   'result': {'loss': 0.3775223333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 86,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 375000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [87],
#                     'gamma': [87],
#                     'learning_rate': [87],
#                     'max_depth': [87],
#                     'min_child_weight': [87],
#                     'reg_alpha': [87],
#                     'reg_lambda': [87],
#                     'subsample': [87]},
#            'tid': 87,
#            'vals': {'colsample_bytree': [0.52],
#                     'gamma': [0.85],
#                     'learning_rate': [0.22],
#                     'max_depth': [4],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.56],
#                     'reg_lambda': [0.44],
#                     'subsample': [0.5]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 441000),
#   'result': {'loss': 0.19682933333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 87,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 519000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [88],
#                     'gamma': [88],
#                     'learning_rate': [88],
#                     'max_depth': [88],
#                     'min_child_weight': [88],
#                     'reg_alpha': [88],
#                     'reg_lambda': [88],
#                     'subsample': [88]},
#            'tid': 88,
#            'vals': {'colsample_bytree': [0.8],
#                     'gamma': [0.92],
#                     'learning_rate': [0.34],
#                     'max_depth': [10],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.9400000000000001],
#                     'reg_lambda': [0.56],
#                     'subsample': [0.6]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 720000),
#   'result': {'loss': 0.25003566666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 88,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 796000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [89],
#                     'gamma': [89],
#                     'learning_rate': [89],
#                     'max_depth': [89],
#                     'min_child_weight': [89],
#                     'reg_alpha': [89],
#                     'reg_lambda': [89],
#                     'subsample': [89]},
#            'tid': 89,
#            'vals': {'colsample_bytree': [0.84],
#                     'gamma': [0.23],
#                     'learning_rate': [0.15],
#                     'max_depth': [16],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.88],
#                     'reg_lambda': [0.29],
#                     'subsample': [0.39]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 832000),
#   'result': {'loss': 0.36034999999999995, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 89,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 908000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [90],
#                     'gamma': [90],
#                     'learning_rate': [90],
#                     'max_depth': [90],
#                     'min_child_weight': [90],
#                     'reg_alpha': [90],
#                     'reg_lambda': [90],
#                     'subsample': [90]},
#            'tid': 90,
#            'vals': {'colsample_bytree': [0.9400000000000001],
#                     'gamma': [0.4],
#                     'learning_rate': [0.38],
#                     'max_depth': [9],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.36],
#                     'reg_lambda': [0.19],
#                     'subsample': [0.98]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 1, 960000),
#   'result': {'loss': 0.29982333333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 90,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 36000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [91],
#                     'gamma': [91],
#                     'learning_rate': [91],
#                     'max_depth': [91],
#                     'min_child_weight': [91],
#                     'reg_alpha': [91],
#                     'reg_lambda': [91],
#                     'subsample': [91]},
#            'tid': 91,
#            'vals': {'colsample_bytree': [0.45],
#                     'gamma': [0.97],
#                     'learning_rate': [0.07],
#                     'max_depth': [2],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.6],
#                     'reg_lambda': [0.17],
#                     'subsample': [0.8300000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 125000),
#   'result': {'loss': 0.2786456666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 91,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 202000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [92],
#                     'gamma': [92],
#                     'learning_rate': [92],
#                     'max_depth': [92],
#                     'min_child_weight': [92],
#                     'reg_alpha': [92],
#                     'reg_lambda': [92],
#                     'subsample': [92]},
#            'tid': 92,
#            'vals': {'colsample_bytree': [0.63],
#                     'gamma': [0.79],
#                     'learning_rate': [0.46],
#                     'max_depth': [8],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.91],
#                     'reg_lambda': [0.65],
#                     'subsample': [0.81]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 249000),
#   'result': {'loss': 0.26455066666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 92,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 325000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [93],
#                     'gamma': [93],
#                     'learning_rate': [93],
#                     'max_depth': [93],
#                     'min_child_weight': [93],
#                     'reg_alpha': [93],
#                     'reg_lambda': [93],
#                     'subsample': [93]},
#            'tid': 93,
#            'vals': {'colsample_bytree': [0.74],
#                     'gamma': [0.74],
#                     'learning_rate': [0.24],
#                     'max_depth': [13],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.27],
#                     'reg_lambda': [0.13],
#                     'subsample': [0.9]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 395000),
#   'result': {'loss': 0.442115, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 93,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 473000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [94],
#                     'gamma': [94],
#                     'learning_rate': [94],
#                     'max_depth': [94],
#                     'min_child_weight': [94],
#                     'reg_alpha': [94],
#                     'reg_lambda': [94],
#                     'subsample': [94]},
#            'tid': 94,
#            'vals': {'colsample_bytree': [0.25],
#                     'gamma': [0.86],
#                     'learning_rate': [0.12],
#                     'max_depth': [6],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.64],
#                     'reg_lambda': [0.22],
#                     'subsample': [0.9400000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 515000),
#   'result': {'loss': 0.187619, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 94,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 594000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [95],
#                     'gamma': [95],
#                     'learning_rate': [95],
#                     'max_depth': [95],
#                     'min_child_weight': [95],
#                     'reg_alpha': [95],
#                     'reg_lambda': [95],
#                     'subsample': [95]},
#            'tid': 95,
#            'vals': {'colsample_bytree': [0.66],
#                     'gamma': [0.5700000000000001],
#                     'learning_rate': [0.26],
#                     'max_depth': [1],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.75],
#                     'reg_lambda': [0.01],
#                     'subsample': [0.78]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 645000),
#   'result': {'loss': 0.3402543333333334, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 95,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 785000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [96],
#                     'gamma': [96],
#                     'learning_rate': [96],
#                     'max_depth': [96],
#                     'min_child_weight': [96],
#                     'reg_alpha': [96],
#                     'reg_lambda': [96],
#                     'subsample': [96]},
#            'tid': 96,
#            'vals': {'colsample_bytree': [0.5700000000000001],
#                     'gamma': [0.17],
#                     'learning_rate': [0.17],
#                     'max_depth': [5],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.84],
#                     'reg_lambda': [0.05],
#                     'subsample': [0.85]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 921000),
#   'result': {'loss': 0.28859166666666664, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 96,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 2, 997000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [97],
#                     'gamma': [97],
#                     'learning_rate': [97],
#                     'max_depth': [97],
#                     'min_child_weight': [97],
#                     'reg_alpha': [97],
#                     'reg_lambda': [97],
#                     'subsample': [97]},
#            'tid': 97,
#            'vals': {'colsample_bytree': [0.89],
#                     'gamma': [0.66],
#                     'learning_rate': [0.14],
#                     'max_depth': [10],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.21],
#                     'reg_lambda': [0.38],
#                     'subsample': [0.88]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 3, 61000),
#   'result': {'loss': 0.35529900000000003, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 97,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 3, 137000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [98],
#                     'gamma': [98],
#                     'learning_rate': [98],
#                     'max_depth': [98],
#                     'min_child_weight': [98],
#                     'reg_alpha': [98],
#                     'reg_lambda': [98],
#                     'subsample': [98]},
#            'tid': 98,
#            'vals': {'colsample_bytree': [0.96],
#                     'gamma': [0.72],
#                     'learning_rate': [0.32],
#                     'max_depth': [0],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.71],
#                     'reg_lambda': [0.35000000000000003],
#                     'subsample': [0.56]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 3, 247000),
#   'result': {'loss': 0.3769963333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 98,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 5, 31, 21, 18, 3, 323000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [99],
#                     'gamma': [99],
#                     'learning_rate': [99],
#                     'max_depth': [99],
#                     'min_child_weight': [99],
#                     'reg_alpha': [99],
#                     'reg_lambda': [99],
#                     'subsample': [99]},
#            'tid': 99,
#            'vals': {'colsample_bytree': [0.6900000000000001],
#                     'gamma': [1.0],
#                     'learning_rate': [0.05],
#                     'max_depth': [10],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.77],
#                     'reg_lambda': [0.32],
#                     'subsample': [0.66]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 5, 31, 21, 18, 3, 375000),
#   'result': {'loss': 0.43520699999999995, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 99,
#   'version': 0}]
