# %% [markdown]
# # Example 04: General Use of XGBoostRegressorHyperOpt
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/slickml/slick-ml/blob/master/examples/optimization/example_04_XGBoostRegressorrHyperOpt.ipynb)

# %% [markdown]
# ### Google Colab Configuration

# %%
# !git clone https://github.com/slickml/slick-ml.git
# %cd slick-ml
# !pip install -r requirements.txt

# %% [markdown]
# ### Local Environment Configuration

# %%
# # Change path to project root
# %cd ../..
# Out:
# /home/amirhessam/Documents/GitHub/slick-ml

# %% [markdown]
# ### Import Python Libraries

# %%
# %load_ext autoreload

# widen the screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

# change the path and loading class
import os, sys
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# %autoreload
from slickml.optimization import XGBoostRegressorHyperOpt
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ----
# # XGBoostRegressorHyperOpt Docstring

# %%
# loading data; note this is a multi regression data
df = pd.read_csv("data/reg_data.csv")
df.head(2)
# Out:
#       F1        F2         F3         F4          F5       F6       F7  \
# 0  1.138  1.543333   289964.0  22.491483  111.289667   7584.0   7584.0
# 1  2.088  3.086667  6960180.0  22.936100  113.807817  28204.0  28204.0
#
#         F8      F9      F10       F11      F12       F13       F14      F15  \
# 0  737.156  561.15  823.713  109600.0  99800.0  594700.0  101900.0  0.07137
# 1  908.551  561.15  854.808  133100.0  99800.0  728200.0  101900.0  0.10655
#
#      F16  TARGET1  TARGET2
# 0  0.082     0.95    0.975
# 1  0.287     0.95    0.975

# %%
# define X, y based on one of the targets
y = df.TARGET1.values
X = df.drop(["TARGET1", "TARGET2"], axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    random_state=1367)

# %%
# define the parameters' bounds
from hyperopt import hp

def get_xgb_params():
    """ Define Parameter Space"""
    params = {
        "nthread": 4,
        "booster": "gbtree",
        "tree_method": "hist",
        "objective": "reg:squarederror",
        "max_depth": hp.choice("max_depth", range(2, 8)),
        "learning_rate": hp.quniform("learning_rate", 0.01, 0.50, 0.01),
        "gamma": hp.quniform("gamma", 0, 0.50, 0.01),
        "min_child_weight": hp.quniform("min_child_weight", 1, 20, 1),
        "subsample": hp.quniform("subsample", 0.1, 1.0, 0.01),
        "colsample_bytree": hp.quniform("colsample_bytree", 0.1, 1.0, 0.01),
        "gamma": hp.quniform("gamma", 0.0, 1.0, 0.01),
        "reg_alpha": hp.quniform("reg_alpha", 0.0, 1.0, 0.01),
        "reg_lambda": hp.quniform("reg_lambda", 0.0, 1.0, 0.01),
    }
    
    return params

# %%
hp.choice("max_depth", range(2, 10, 1))

# %%
# initialize XGBoostRegressorHyperOpt
xho = XGBoostRegressorHyperOpt(num_boost_round=200,
                                metrics="rmse",
                                n_splits=4,
                                shuffle=True,
                                early_stopping_rounds=20,
                                func_name="xgb_cv",
                                space=get_xgb_params(),
                                max_evals=100,
                                verbose=False
                               )
# fit 
xho.fit(X_train,y_train)
# Out:
# 100%|██████████| 100/100 [01:07<00:00,  1.47trial/s, best loss: 0.007824]

# %% [markdown]
# ### Best set of parameters from all runs

# %%
xho.get_optimization_results()
# Out:
#    colsample_bytree  gamma  learning_rate  max_depth  min_child_weight  \
# 0              0.69   0.41           0.08          1              10.0
#
#    reg_alpha  reg_lambda  subsample
# 0       0.59         0.2       0.52

# %% [markdown]
# ### Results from each trial

# %%
import pprint
pprint.pprint(xho.get_optimization_trials().trials)
# Out:
# [{'book_time': datetime.datetime(2021, 6, 6, 23, 35, 22, 484000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [0],
#                     'gamma': [0],
#                     'learning_rate': [0],
#                     'max_depth': [0],
#                     'min_child_weight': [0],
#                     'reg_alpha': [0],
#                     'reg_lambda': [0],
#                     'subsample': [0]},
#            'tid': 0,
#            'vals': {'colsample_bytree': [0.9],
#                     'gamma': [0.23],
#                     'learning_rate': [0.29],
#                     'max_depth': [2],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.59],
#                     'reg_lambda': [0.87],
#                     'subsample': [0.97]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 23, 37000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 0,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 23, 43000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [1],
#                     'gamma': [1],
#                     'learning_rate': [1],
#                     'max_depth': [1],
#                     'min_child_weight': [1],
#                     'reg_alpha': [1],
#                     'reg_lambda': [1],
#                     'subsample': [1]},
#            'tid': 1,
#            'vals': {'colsample_bytree': [0.93],
#                     'gamma': [0.47000000000000003],
#                     'learning_rate': [0.38],
#                     'max_depth': [3],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.93],
#                     'reg_lambda': [0.64],
#                     'subsample': [0.61]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 23, 611000),
#   'result': {'loss': 0.014721749999999999, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 1,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 23, 617000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [2],
#                     'gamma': [2],
#                     'learning_rate': [2],
#                     'max_depth': [2],
#                     'min_child_weight': [2],
#                     'reg_alpha': [2],
#                     'reg_lambda': [2],
#                     'subsample': [2]},
#            'tid': 2,
#            'vals': {'colsample_bytree': [0.61],
#                     'gamma': [0.37],
#                     'learning_rate': [0.26],
#                     'max_depth': [3],
#                     'min_child_weight': [19.0],
#                     'reg_alpha': [0.71],
#                     'reg_lambda': [0.37],
#                     'subsample': [0.35000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 23, 961000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 2,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 23, 967000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [3],
#                     'gamma': [3],
#                     'learning_rate': [3],
#                     'max_depth': [3],
#                     'min_child_weight': [3],
#                     'reg_alpha': [3],
#                     'reg_lambda': [3],
#                     'subsample': [3]},
#            'tid': 3,
#            'vals': {'colsample_bytree': [0.59],
#                     'gamma': [0.8300000000000001],
#                     'learning_rate': [0.19],
#                     'max_depth': [1],
#                     'min_child_weight': [19.0],
#                     'reg_alpha': [0.04],
#                     'reg_lambda': [0.07],
#                     'subsample': [0.45]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 24, 781000),
#   'result': {'loss': 0.014777, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 3,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 24, 787000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [4],
#                     'gamma': [4],
#                     'learning_rate': [4],
#                     'max_depth': [4],
#                     'min_child_weight': [4],
#                     'reg_alpha': [4],
#                     'reg_lambda': [4],
#                     'subsample': [4]},
#            'tid': 4,
#            'vals': {'colsample_bytree': [0.93],
#                     'gamma': [0.53],
#                     'learning_rate': [0.06],
#                     'max_depth': [3],
#                     'min_child_weight': [17.0],
#                     'reg_alpha': [0.64],
#                     'reg_lambda': [0.06],
#                     'subsample': [0.17]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 25, 206000),
#   'result': {'loss': 0.01472125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 4,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 25, 212000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [5],
#                     'gamma': [5],
#                     'learning_rate': [5],
#                     'max_depth': [5],
#                     'min_child_weight': [5],
#                     'reg_alpha': [5],
#                     'reg_lambda': [5],
#                     'subsample': [5]},
#            'tid': 5,
#            'vals': {'colsample_bytree': [0.23],
#                     'gamma': [0.06],
#                     'learning_rate': [0.21],
#                     'max_depth': [4],
#                     'min_child_weight': [14.0],
#                     'reg_alpha': [0.71],
#                     'reg_lambda': [0.9400000000000001],
#                     'subsample': [0.51]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 25, 583000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 5,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 25, 589000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [6],
#                     'gamma': [6],
#                     'learning_rate': [6],
#                     'max_depth': [6],
#                     'min_child_weight': [6],
#                     'reg_alpha': [6],
#                     'reg_lambda': [6],
#                     'subsample': [6]},
#            'tid': 6,
#            'vals': {'colsample_bytree': [0.46],
#                     'gamma': [1.0],
#                     'learning_rate': [0.36],
#                     'max_depth': [1],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.97],
#                     'reg_lambda': [0.29],
#                     'subsample': [0.65]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 26, 203000),
#   'result': {'loss': 0.00946875, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 6,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 26, 209000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [7],
#                     'gamma': [7],
#                     'learning_rate': [7],
#                     'max_depth': [7],
#                     'min_child_weight': [7],
#                     'reg_alpha': [7],
#                     'reg_lambda': [7],
#                     'subsample': [7]},
#            'tid': 7,
#            'vals': {'colsample_bytree': [0.6900000000000001],
#                     'gamma': [0.41000000000000003],
#                     'learning_rate': [0.08],
#                     'max_depth': [1],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.59],
#                     'reg_lambda': [0.2],
#                     'subsample': [0.52]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 26, 620000),
#   'result': {'loss': 0.007824, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 7,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 26, 627000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [8],
#                     'gamma': [8],
#                     'learning_rate': [8],
#                     'max_depth': [8],
#                     'min_child_weight': [8],
#                     'reg_alpha': [8],
#                     'reg_lambda': [8],
#                     'subsample': [8]},
#            'tid': 8,
#            'vals': {'colsample_bytree': [0.39],
#                     'gamma': [0.23],
#                     'learning_rate': [0.17],
#                     'max_depth': [4],
#                     'min_child_weight': [17.0],
#                     'reg_alpha': [0.05],
#                     'reg_lambda': [0.73],
#                     'subsample': [0.37]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 27, 1000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 8,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 27, 7000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [9],
#                     'gamma': [9],
#                     'learning_rate': [9],
#                     'max_depth': [9],
#                     'min_child_weight': [9],
#                     'reg_alpha': [9],
#                     'reg_lambda': [9],
#                     'subsample': [9]},
#            'tid': 9,
#            'vals': {'colsample_bytree': [0.49],
#                     'gamma': [0.29],
#                     'learning_rate': [0.2],
#                     'max_depth': [0],
#                     'min_child_weight': [12.0],
#                     'reg_alpha': [0.64],
#                     'reg_lambda': [0.8],
#                     'subsample': [0.3]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 27, 430000),
#   'result': {'loss': 0.014721749999999999, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 9,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 27, 437000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [10],
#                     'gamma': [10],
#                     'learning_rate': [10],
#                     'max_depth': [10],
#                     'min_child_weight': [10],
#                     'reg_alpha': [10],
#                     'reg_lambda': [10],
#                     'subsample': [10]},
#            'tid': 10,
#            'vals': {'colsample_bytree': [0.38],
#                     'gamma': [0.27],
#                     'learning_rate': [0.32],
#                     'max_depth': [5],
#                     'min_child_weight': [18.0],
#                     'reg_alpha': [0.81],
#                     'reg_lambda': [0.44],
#                     'subsample': [0.23]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 27, 860000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 10,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 27, 866000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [11],
#                     'gamma': [11],
#                     'learning_rate': [11],
#                     'max_depth': [11],
#                     'min_child_weight': [11],
#                     'reg_alpha': [11],
#                     'reg_lambda': [11],
#                     'subsample': [11]},
#            'tid': 11,
#            'vals': {'colsample_bytree': [0.33],
#                     'gamma': [0.08],
#                     'learning_rate': [0.19],
#                     'max_depth': [2],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.86],
#                     'reg_lambda': [0.12],
#                     'subsample': [0.49]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 28, 254000),
#   'result': {'loss': 0.01472125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 11,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 28, 260000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [12],
#                     'gamma': [12],
#                     'learning_rate': [12],
#                     'max_depth': [12],
#                     'min_child_weight': [12],
#                     'reg_alpha': [12],
#                     'reg_lambda': [12],
#                     'subsample': [12]},
#            'tid': 12,
#            'vals': {'colsample_bytree': [0.21],
#                     'gamma': [0.5700000000000001],
#                     'learning_rate': [0.31],
#                     'max_depth': [1],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.38],
#                     'reg_lambda': [0.12],
#                     'subsample': [0.34]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 28, 754000),
#   'result': {'loss': 0.00956175, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 12,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 28, 762000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [13],
#                     'gamma': [13],
#                     'learning_rate': [13],
#                     'max_depth': [13],
#                     'min_child_weight': [13],
#                     'reg_alpha': [13],
#                     'reg_lambda': [13],
#                     'subsample': [13]},
#            'tid': 13,
#            'vals': {'colsample_bytree': [0.87],
#                     'gamma': [0.67],
#                     'learning_rate': [0.23],
#                     'max_depth': [4],
#                     'min_child_weight': [16.0],
#                     'reg_alpha': [0.42],
#                     'reg_lambda': [0.81],
#                     'subsample': [0.89]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 29, 176000),
#   'result': {'loss': 0.01472075, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 13,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 29, 181000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [14],
#                     'gamma': [14],
#                     'learning_rate': [14],
#                     'max_depth': [14],
#                     'min_child_weight': [14],
#                     'reg_alpha': [14],
#                     'reg_lambda': [14],
#                     'subsample': [14]},
#            'tid': 14,
#            'vals': {'colsample_bytree': [0.38],
#                     'gamma': [0.28],
#                     'learning_rate': [0.2],
#                     'max_depth': [3],
#                     'min_child_weight': [16.0],
#                     'reg_alpha': [0.79],
#                     'reg_lambda': [0.42],
#                     'subsample': [0.87]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 29, 696000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 14,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 29, 702000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [15],
#                     'gamma': [15],
#                     'learning_rate': [15],
#                     'max_depth': [15],
#                     'min_child_weight': [15],
#                     'reg_alpha': [15],
#                     'reg_lambda': [15],
#                     'subsample': [15]},
#            'tid': 15,
#            'vals': {'colsample_bytree': [0.86],
#                     'gamma': [0.6900000000000001],
#                     'learning_rate': [0.27],
#                     'max_depth': [4],
#                     'min_child_weight': [17.0],
#                     'reg_alpha': [0.9400000000000001],
#                     'reg_lambda': [0.7000000000000001],
#                     'subsample': [0.53]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 30, 202000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 15,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 30, 209000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [16],
#                     'gamma': [16],
#                     'learning_rate': [16],
#                     'max_depth': [16],
#                     'min_child_weight': [16],
#                     'reg_alpha': [16],
#                     'reg_lambda': [16],
#                     'subsample': [16]},
#            'tid': 16,
#            'vals': {'colsample_bytree': [0.9500000000000001],
#                     'gamma': [0.9400000000000001],
#                     'learning_rate': [0.45],
#                     'max_depth': [0],
#                     'min_child_weight': [18.0],
#                     'reg_alpha': [0.51],
#                     'reg_lambda': [0.8],
#                     'subsample': [0.4]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 30, 600000),
#   'result': {'loss': 0.01472125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 16,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 30, 606000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [17],
#                     'gamma': [17],
#                     'learning_rate': [17],
#                     'max_depth': [17],
#                     'min_child_weight': [17],
#                     'reg_alpha': [17],
#                     'reg_lambda': [17],
#                     'subsample': [17]},
#            'tid': 17,
#            'vals': {'colsample_bytree': [0.65],
#                     'gamma': [0.71],
#                     'learning_rate': [0.08],
#                     'max_depth': [4],
#                     'min_child_weight': [15.0],
#                     'reg_alpha': [0.6900000000000001],
#                     'reg_lambda': [0.42],
#                     'subsample': [0.88]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 31, 783000),
#   'result': {'loss': 0.0653715, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 17,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 31, 790000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [18],
#                     'gamma': [18],
#                     'learning_rate': [18],
#                     'max_depth': [18],
#                     'min_child_weight': [18],
#                     'reg_alpha': [18],
#                     'reg_lambda': [18],
#                     'subsample': [18]},
#            'tid': 18,
#            'vals': {'colsample_bytree': [0.48],
#                     'gamma': [0.73],
#                     'learning_rate': [0.26],
#                     'max_depth': [2],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.21],
#                     'reg_lambda': [0.85],
#                     'subsample': [0.44]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 32, 124000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 18,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 32, 132000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [19],
#                     'gamma': [19],
#                     'learning_rate': [19],
#                     'max_depth': [19],
#                     'min_child_weight': [19],
#                     'reg_alpha': [19],
#                     'reg_lambda': [19],
#                     'subsample': [19]},
#            'tid': 19,
#            'vals': {'colsample_bytree': [0.23],
#                     'gamma': [0.99],
#                     'learning_rate': [0.1],
#                     'max_depth': [0],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.55],
#                     'reg_lambda': [0.6],
#                     'subsample': [0.36]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 33, 130000),
#   'result': {'loss': 0.014725499999999999, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 19,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 33, 171000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [20],
#                     'gamma': [20],
#                     'learning_rate': [20],
#                     'max_depth': [20],
#                     'min_child_weight': [20],
#                     'reg_alpha': [20],
#                     'reg_lambda': [20],
#                     'subsample': [20]},
#            'tid': 20,
#            'vals': {'colsample_bytree': [0.73],
#                     'gamma': [0.44],
#                     'learning_rate': [0.49],
#                     'max_depth': [1],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.29],
#                     'reg_lambda': [0.26],
#                     'subsample': [0.67]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 33, 943000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 20,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 33, 984000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [21],
#                     'gamma': [21],
#                     'learning_rate': [21],
#                     'max_depth': [21],
#                     'min_child_weight': [21],
#                     'reg_alpha': [21],
#                     'reg_lambda': [21],
#                     'subsample': [21]},
#            'tid': 21,
#            'vals': {'colsample_bytree': [0.78],
#                     'gamma': [0.9],
#                     'learning_rate': [0.39],
#                     'max_depth': [1],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [1.0],
#                     'reg_lambda': [0.22],
#                     'subsample': [0.7000000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 34, 404000),
#   'result': {'loss': 0.01472125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 21,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 34, 451000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [22],
#                     'gamma': [22],
#                     'learning_rate': [22],
#                     'max_depth': [22],
#                     'min_child_weight': [22],
#                     'reg_alpha': [22],
#                     'reg_lambda': [22],
#                     'subsample': [22]},
#            'tid': 22,
#            'vals': {'colsample_bytree': [0.7000000000000001],
#                     'gamma': [0.6],
#                     'learning_rate': [0.13],
#                     'max_depth': [1],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.17],
#                     'reg_lambda': [0.28],
#                     'subsample': [0.76]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 34, 814000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 22,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 34, 854000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [23],
#                     'gamma': [23],
#                     'learning_rate': [23],
#                     'max_depth': [23],
#                     'min_child_weight': [23],
#                     'reg_alpha': [23],
#                     'reg_lambda': [23],
#                     'subsample': [23]},
#            'tid': 23,
#            'vals': {'colsample_bytree': [0.12],
#                     'gamma': [0.15],
#                     'learning_rate': [0.36],
#                     'max_depth': [1],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.42],
#                     'reg_lambda': [0.54],
#                     'subsample': [0.6]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 35, 235000),
#   'result': {'loss': 0.0147215, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 23,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 35, 283000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [24],
#                     'gamma': [24],
#                     'learning_rate': [24],
#                     'max_depth': [24],
#                     'min_child_weight': [24],
#                     'reg_alpha': [24],
#                     'reg_lambda': [24],
#                     'subsample': [24]},
#            'tid': 24,
#            'vals': {'colsample_bytree': [0.54],
#                     'gamma': [0.39],
#                     'learning_rate': [0.01],
#                     'max_depth': [5],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.98],
#                     'reg_lambda': [0.2],
#                     'subsample': [0.76]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 35, 732000),
#   'result': {'loss': 0.01472125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 24,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 35, 774000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [25],
#                     'gamma': [25],
#                     'learning_rate': [25],
#                     'max_depth': [25],
#                     'min_child_weight': [25],
#                     'reg_alpha': [25],
#                     'reg_lambda': [25],
#                     'subsample': [25]},
#            'tid': 25,
#            'vals': {'colsample_bytree': [0.81],
#                     'gamma': [0.81],
#                     'learning_rate': [0.43],
#                     'max_depth': [1],
#                     'min_child_weight': [12.0],
#                     'reg_alpha': [0.88],
#                     'reg_lambda': [0.32],
#                     'subsample': [0.62]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 36, 916000),
#   'result': {'loss': 0.01472125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 25,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 36, 955000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [26],
#                     'gamma': [26],
#                     'learning_rate': [26],
#                     'max_depth': [26],
#                     'min_child_weight': [26],
#                     'reg_alpha': [26],
#                     'reg_lambda': [26],
#                     'subsample': [26]},
#            'tid': 26,
#            'vals': {'colsample_bytree': [0.47000000000000003],
#                     'gamma': [0.38],
#                     'learning_rate': [0.49],
#                     'max_depth': [1],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.78],
#                     'reg_lambda': [0.01],
#                     'subsample': [0.79]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 37, 317000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 26,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 37, 358000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [27],
#                     'gamma': [27],
#                     'learning_rate': [27],
#                     'max_depth': [27],
#                     'min_child_weight': [27],
#                     'reg_alpha': [27],
#                     'reg_lambda': [27],
#                     'subsample': [27]},
#            'tid': 27,
#            'vals': {'colsample_bytree': [0.68],
#                     'gamma': [0.61],
#                     'learning_rate': [0.14],
#                     'max_depth': [5],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.33],
#                     'reg_lambda': [0.17],
#                     'subsample': [0.1]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 37, 596000),
#   'result': {'loss': 0.014725499999999999, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 27,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 37, 637000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [28],
#                     'gamma': [28],
#                     'learning_rate': [28],
#                     'max_depth': [28],
#                     'min_child_weight': [28],
#                     'reg_alpha': [28],
#                     'reg_lambda': [28],
#                     'subsample': [28]},
#            'tid': 28,
#            'vals': {'colsample_bytree': [1.0],
#                     'gamma': [0.19],
#                     'learning_rate': [0.02],
#                     'max_depth': [1],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.55],
#                     'reg_lambda': [0.51],
#                     'subsample': [0.98]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 38, 630000),
#   'result': {'loss': 0.014721999999999999, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 28,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 38, 672000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [29],
#                     'gamma': [29],
#                     'learning_rate': [29],
#                     'max_depth': [29],
#                     'min_child_weight': [29],
#                     'reg_alpha': [29],
#                     'reg_lambda': [29],
#                     'subsample': [29]},
#            'tid': 29,
#            'vals': {'colsample_bytree': [0.54],
#                     'gamma': [0.51],
#                     'learning_rate': [0.34],
#                     'max_depth': [2],
#                     'min_child_weight': [12.0],
#                     'reg_alpha': [0.15],
#                     'reg_lambda': [0.33],
#                     'subsample': [0.56]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 39, 630000),
#   'result': {'loss': 0.01472375, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 29,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 39, 672000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [30],
#                     'gamma': [30],
#                     'learning_rate': [30],
#                     'max_depth': [30],
#                     'min_child_weight': [30],
#                     'reg_alpha': [30],
#                     'reg_lambda': [30],
#                     'subsample': [30]},
#            'tid': 30,
#            'vals': {'colsample_bytree': [0.28],
#                     'gamma': [0.0],
#                     'learning_rate': [0.39],
#                     'max_depth': [1],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.6],
#                     'reg_lambda': [0.0],
#                     'subsample': [0.66]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 40, 21000),
#   'result': {'loss': 0.01472125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 30,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 40, 64000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [31],
#                     'gamma': [31],
#                     'learning_rate': [31],
#                     'max_depth': [31],
#                     'min_child_weight': [31],
#                     'reg_alpha': [31],
#                     'reg_lambda': [31],
#                     'subsample': [31]},
#            'tid': 31,
#            'vals': {'colsample_bytree': [0.76],
#                     'gamma': [0.45],
#                     'learning_rate': [0.43],
#                     'max_depth': [1],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.88],
#                     'reg_lambda': [0.35000000000000003],
#                     'subsample': [0.8300000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 40, 571000),
#   'result': {'loss': 0.01472075, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 31,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 40, 617000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [32],
#                     'gamma': [32],
#                     'learning_rate': [32],
#                     'max_depth': [32],
#                     'min_child_weight': [32],
#                     'reg_alpha': [32],
#                     'reg_lambda': [32],
#                     'subsample': [32]},
#            'tid': 32,
#            'vals': {'colsample_bytree': [0.61],
#                     'gamma': [0.79],
#                     'learning_rate': [0.29],
#                     'max_depth': [3],
#                     'min_child_weight': [14.0],
#                     'reg_alpha': [0.46],
#                     'reg_lambda': [0.15],
#                     'subsample': [0.71]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 40, 873000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 32,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 40, 915000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [33],
#                     'gamma': [33],
#                     'learning_rate': [33],
#                     'max_depth': [33],
#                     'min_child_weight': [33],
#                     'reg_alpha': [33],
#                     'reg_lambda': [33],
#                     'subsample': [33]},
#            'tid': 33,
#            'vals': {'colsample_bytree': [0.44],
#                     'gamma': [0.35000000000000003],
#                     'learning_rate': [0.04],
#                     'max_depth': [1],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.73],
#                     'reg_lambda': [0.08],
#                     'subsample': [0.28]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 41, 350000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 33,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 41, 395000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [34],
#                     'gamma': [34],
#                     'learning_rate': [34],
#                     'max_depth': [34],
#                     'min_child_weight': [34],
#                     'reg_alpha': [34],
#                     'reg_lambda': [34],
#                     'subsample': [34]},
#            'tid': 34,
#            'vals': {'colsample_bytree': [0.11],
#                     'gamma': [0.13],
#                     'learning_rate': [0.15],
#                     'max_depth': [5],
#                     'min_child_weight': [13.0],
#                     'reg_alpha': [0.96],
#                     'reg_lambda': [0.26],
#                     'subsample': [0.46]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 41, 858000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 34,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 41, 902000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [35],
#                     'gamma': [35],
#                     'learning_rate': [35],
#                     'max_depth': [35],
#                     'min_child_weight': [35],
#                     'reg_alpha': [35],
#                     'reg_lambda': [35],
#                     'subsample': [35]},
#            'tid': 35,
#            'vals': {'colsample_bytree': [0.5700000000000001],
#                     'gamma': [0.87],
#                     'learning_rate': [0.24],
#                     'max_depth': [0],
#                     'min_child_weight': [11.0],
#                     'reg_alpha': [0.28],
#                     'reg_lambda': [0.55],
#                     'subsample': [0.5700000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 42, 241000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 35,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 42, 286000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [36],
#                     'gamma': [36],
#                     'learning_rate': [36],
#                     'max_depth': [36],
#                     'min_child_weight': [36],
#                     'reg_alpha': [36],
#                     'reg_lambda': [36],
#                     'subsample': [36]},
#            'tid': 36,
#            'vals': {'colsample_bytree': [0.64],
#                     'gamma': [0.54],
#                     'learning_rate': [0.37],
#                     'max_depth': [3],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.01],
#                     'reg_lambda': [0.47000000000000003],
#                     'subsample': [0.63]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 42, 702000),
#   'result': {'loss': 0.01472125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 36,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 42, 749000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [37],
#                     'gamma': [37],
#                     'learning_rate': [37],
#                     'max_depth': [37],
#                     'min_child_weight': [37],
#                     'reg_alpha': [37],
#                     'reg_lambda': [37],
#                     'subsample': [37]},
#            'tid': 37,
#            'vals': {'colsample_bytree': [0.43],
#                     'gamma': [0.64],
#                     'learning_rate': [0.1],
#                     'max_depth': [2],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.08],
#                     'reg_lambda': [0.97],
#                     'subsample': [0.93]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 43, 335000),
#   'result': {'loss': 0.0147215, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 37,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 43, 384000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [38],
#                     'gamma': [38],
#                     'learning_rate': [38],
#                     'max_depth': [38],
#                     'min_child_weight': [38],
#                     'reg_alpha': [38],
#                     'reg_lambda': [38],
#                     'subsample': [38]},
#            'tid': 38,
#            'vals': {'colsample_bytree': [0.32],
#                     'gamma': [0.99],
#                     'learning_rate': [0.46],
#                     'max_depth': [1],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.63],
#                     'reg_lambda': [0.38],
#                     'subsample': [0.16]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 43, 888000),
#   'result': {'loss': 0.014721999999999999, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 38,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 43, 934000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [39],
#                     'gamma': [39],
#                     'learning_rate': [39],
#                     'max_depth': [39],
#                     'min_child_weight': [39],
#                     'reg_alpha': [39],
#                     'reg_lambda': [39],
#                     'subsample': [39]},
#            'tid': 39,
#            'vals': {'colsample_bytree': [0.8200000000000001],
#                     'gamma': [0.33],
#                     'learning_rate': [0.41000000000000003],
#                     'max_depth': [1],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.68],
#                     'reg_lambda': [0.04],
#                     'subsample': [0.48]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 44, 277000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 39,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 44, 324000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [40],
#                     'gamma': [40],
#                     'learning_rate': [40],
#                     'max_depth': [40],
#                     'min_child_weight': [40],
#                     'reg_alpha': [40],
#                     'reg_lambda': [40],
#                     'subsample': [40]},
#            'tid': 40,
#            'vals': {'colsample_bytree': [0.18],
#                     'gamma': [0.47000000000000003],
#                     'learning_rate': [0.33],
#                     'max_depth': [0],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.86],
#                     'reg_lambda': [0.22],
#                     'subsample': [0.42]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 44, 584000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 40,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 44, 638000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [41],
#                     'gamma': [41],
#                     'learning_rate': [41],
#                     'max_depth': [41],
#                     'min_child_weight': [41],
#                     'reg_alpha': [41],
#                     'reg_lambda': [41],
#                     'subsample': [41]},
#            'tid': 41,
#            'vals': {'colsample_bytree': [0.51],
#                     'gamma': [0.01],
#                     'learning_rate': [0.28],
#                     'max_depth': [3],
#                     'min_child_weight': [11.0],
#                     'reg_alpha': [0.75],
#                     'reg_lambda': [0.1],
#                     'subsample': [0.25]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 44, 910000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 41,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 44, 959000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [42],
#                     'gamma': [42],
#                     'learning_rate': [42],
#                     'max_depth': [42],
#                     'min_child_weight': [42],
#                     'reg_alpha': [42],
#                     'reg_lambda': [42],
#                     'subsample': [42]},
#            'tid': 42,
#            'vals': {'colsample_bytree': [0.62],
#                     'gamma': [0.78],
#                     'learning_rate': [0.17],
#                     'max_depth': [4],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.8300000000000001],
#                     'reg_lambda': [0.63],
#                     'subsample': [0.53]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 45, 864000),
#   'result': {'loss': 0.01467525, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 42,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 45, 914000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [43],
#                     'gamma': [43],
#                     'learning_rate': [43],
#                     'max_depth': [43],
#                     'min_child_weight': [43],
#                     'reg_alpha': [43],
#                     'reg_lambda': [43],
#                     'subsample': [43]},
#            'tid': 43,
#            'vals': {'colsample_bytree': [0.35000000000000003],
#                     'gamma': [0.23],
#                     'learning_rate': [0.3],
#                     'max_depth': [5],
#                     'min_child_weight': [14.0],
#                     'reg_alpha': [0.92],
#                     'reg_lambda': [0.38],
#                     'subsample': [0.32]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 46, 865000),
#   'result': {'loss': 0.06533, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 43,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 35, 46, 916000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [44],
#                     'gamma': [44],
#                     'learning_rate': [44],
#                     'max_depth': [44],
#                     'min_child_weight': [44],
#                     'reg_alpha': [44],
#                     'reg_lambda': [44],
#                     'subsample': [44]},
#            'tid': 44,
#            'vals': {'colsample_bytree': [0.42],
#                     'gamma': [0.75],
#                     'learning_rate': [0.23],
#                     'max_depth': [2],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.49],
#                     'reg_lambda': [0.3],
#                     'subsample': [0.4]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 35, 47, 842000),
#   'result': {'loss': 0.0147215, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 44,
#   'version': 0},
# ...
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [85],
#                     'gamma': [85],
#                     'learning_rate': [85],
#                     'max_depth': [85],
#                     'min_child_weight': [85],
#                     'reg_alpha': [85],
#                     'reg_lambda': [85],
#                     'subsample': [85]},
#            'tid': 85,
#            'vals': {'colsample_bytree': [0.37],
#                     'gamma': [0.63],
#                     'learning_rate': [0.04],
#                     'max_depth': [4],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.06],
#                     'reg_lambda': [0.42],
#                     'subsample': [0.45]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 22, 195000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 85,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 22, 273000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [86],
#                     'gamma': [86],
#                     'learning_rate': [86],
#                     'max_depth': [86],
#                     'min_child_weight': [86],
#                     'reg_alpha': [86],
#                     'reg_lambda': [86],
#                     'subsample': [86]},
#            'tid': 86,
#            'vals': {'colsample_bytree': [0.67],
#                     'gamma': [0.72],
#                     'learning_rate': [0.22],
#                     'max_depth': [1],
#                     'min_child_weight': [11.0],
#                     'reg_alpha': [0.77],
#                     'reg_lambda': [0.27],
#                     'subsample': [0.6]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 22, 775000),
#   'result': {'loss': 0.01123775, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 86,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 22, 855000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [87],
#                     'gamma': [87],
#                     'learning_rate': [87],
#                     'max_depth': [87],
#                     'min_child_weight': [87],
#                     'reg_alpha': [87],
#                     'reg_lambda': [87],
#                     'subsample': [87]},
#            'tid': 87,
#            'vals': {'colsample_bytree': [0.62],
#                     'gamma': [0.5],
#                     'learning_rate': [0.19],
#                     'max_depth': [0],
#                     'min_child_weight': [14.0],
#                     'reg_alpha': [0.56],
#                     'reg_lambda': [0.5700000000000001],
#                     'subsample': [0.27]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 23, 306000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 87,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 23, 393000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [88],
#                     'gamma': [88],
#                     'learning_rate': [88],
#                     'max_depth': [88],
#                     'min_child_weight': [88],
#                     'reg_alpha': [88],
#                     'reg_lambda': [88],
#                     'subsample': [88]},
#            'tid': 88,
#            'vals': {'colsample_bytree': [0.56],
#                     'gamma': [0.41000000000000003],
#                     'learning_rate': [0.25],
#                     'max_depth': [1],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.89],
#                     'reg_lambda': [0.01],
#                     'subsample': [0.71]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 23, 798000),
#   'result': {'loss': 0.01472075, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 88,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 23, 878000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [89],
#                     'gamma': [89],
#                     'learning_rate': [89],
#                     'max_depth': [89],
#                     'min_child_weight': [89],
#                     'reg_alpha': [89],
#                     'reg_lambda': [89],
#                     'subsample': [89]},
#            'tid': 89,
#            'vals': {'colsample_bytree': [0.46],
#                     'gamma': [0.37],
#                     'learning_rate': [0.45],
#                     'max_depth': [3],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.97],
#                     'reg_lambda': [0.05],
#                     'subsample': [0.55]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 24, 733000),
#   'result': {'loss': 0.01472225, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 89,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 24, 810000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [90],
#                     'gamma': [90],
#                     'learning_rate': [90],
#                     'max_depth': [90],
#                     'min_child_weight': [90],
#                     'reg_alpha': [90],
#                     'reg_lambda': [90],
#                     'subsample': [90]},
#            'tid': 90,
#            'vals': {'colsample_bytree': [0.42],
#                     'gamma': [0.5700000000000001],
#                     'learning_rate': [0.28],
#                     'max_depth': [1],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.44],
#                     'reg_lambda': [0.13],
#                     'subsample': [0.41000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 25, 93000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 90,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 25, 170000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [91],
#                     'gamma': [91],
#                     'learning_rate': [91],
#                     'max_depth': [91],
#                     'min_child_weight': [91],
#                     'reg_alpha': [91],
#                     'reg_lambda': [91],
#                     'subsample': [91]},
#            'tid': 91,
#            'vals': {'colsample_bytree': [0.27],
#                     'gamma': [0.6],
#                     'learning_rate': [0.37],
#                     'max_depth': [2],
#                     'min_child_weight': [19.0],
#                     'reg_alpha': [0.62],
#                     'reg_lambda': [0.36],
#                     'subsample': [0.66]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 25, 670000),
#   'result': {'loss': 0.013222500000000002, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 91,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 25, 748000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [92],
#                     'gamma': [92],
#                     'learning_rate': [92],
#                     'max_depth': [92],
#                     'min_child_weight': [92],
#                     'reg_alpha': [92],
#                     'reg_lambda': [92],
#                     'subsample': [92]},
#            'tid': 92,
#            'vals': {'colsample_bytree': [0.52],
#                     'gamma': [0.11],
#                     'learning_rate': [0.33],
#                     'max_depth': [5],
#                     'min_child_weight': [12.0],
#                     'reg_alpha': [0.19],
#                     'reg_lambda': [0.52],
#                     'subsample': [0.62]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 26, 606000),
#   'result': {'loss': 0.06538025, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 92,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 26, 683000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [93],
#                     'gamma': [93],
#                     'learning_rate': [93],
#                     'max_depth': [93],
#                     'min_child_weight': [93],
#                     'reg_alpha': [93],
#                     'reg_lambda': [93],
#                     'subsample': [93]},
#            'tid': 93,
#            'vals': {'colsample_bytree': [0.3],
#                     'gamma': [0.04],
#                     'learning_rate': [0.4],
#                     'max_depth': [4],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.31],
#                     'reg_lambda': [0.1],
#                     'subsample': [0.37]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 26, 959000),
#   'result': {'loss': 0.014721999999999999, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 93,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 27, 35000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [94],
#                     'gamma': [94],
#                     'learning_rate': [94],
#                     'max_depth': [94],
#                     'min_child_weight': [94],
#                     'reg_alpha': [94],
#                     'reg_lambda': [94],
#                     'subsample': [94]},
#            'tid': 94,
#            'vals': {'colsample_bytree': [0.74],
#                     'gamma': [0.47000000000000003],
#                     'learning_rate': [0.14],
#                     'max_depth': [1],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.46],
#                     'reg_lambda': [0.31],
#                     'subsample': [0.8200000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 27, 335000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 94,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 27, 410000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [95],
#                     'gamma': [95],
#                     'learning_rate': [95],
#                     'max_depth': [95],
#                     'min_child_weight': [95],
#                     'reg_alpha': [95],
#                     'reg_lambda': [95],
#                     'subsample': [95]},
#            'tid': 95,
#            'vals': {'colsample_bytree': [0.8],
#                     'gamma': [0.17],
#                     'learning_rate': [0.06],
#                     'max_depth': [1],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.5],
#                     'reg_lambda': [0.22],
#                     'subsample': [0.58]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 27, 722000),
#   'result': {'loss': 0.01472125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 95,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 27, 798000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [96],
#                     'gamma': [96],
#                     'learning_rate': [96],
#                     'max_depth': [96],
#                     'min_child_weight': [96],
#                     'reg_alpha': [96],
#                     'reg_lambda': [96],
#                     'subsample': [96]},
#            'tid': 96,
#            'vals': {'colsample_bytree': [0.66],
#                     'gamma': [0.45],
#                     'learning_rate': [0.5],
#                     'max_depth': [0],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.4],
#                     'reg_lambda': [0.0],
#                     'subsample': [0.86]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 28, 194000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 96,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 28, 270000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [97],
#                     'gamma': [97],
#                     'learning_rate': [97],
#                     'max_depth': [97],
#                     'min_child_weight': [97],
#                     'reg_alpha': [97],
#                     'reg_lambda': [97],
#                     'subsample': [97]},
#            'tid': 97,
#            'vals': {'colsample_bytree': [0.39],
#                     'gamma': [0.68],
#                     'learning_rate': [0.3],
#                     'max_depth': [1],
#                     'min_child_weight': [15.0],
#                     'reg_alpha': [0.26],
#                     'reg_lambda': [0.08],
#                     'subsample': [0.8]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 28, 816000),
#   'result': {'loss': 0.014721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 97,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 28, 892000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [98],
#                     'gamma': [98],
#                     'learning_rate': [98],
#                     'max_depth': [98],
#                     'min_child_weight': [98],
#                     'reg_alpha': [98],
#                     'reg_lambda': [98],
#                     'subsample': [98]},
#            'tid': 98,
#            'vals': {'colsample_bytree': [0.54],
#                     'gamma': [0.86],
#                     'learning_rate': [0.18],
#                     'max_depth': [3],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.99],
#                     'reg_lambda': [0.62],
#                     'subsample': [0.35000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 29, 240000),
#   'result': {'loss': 0.01472075, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 98,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 6, 6, 23, 36, 29, 316000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [99],
#                     'gamma': [99],
#                     'learning_rate': [99],
#                     'max_depth': [99],
#                     'min_child_weight': [99],
#                     'reg_alpha': [99],
#                     'reg_lambda': [99],
#                     'subsample': [99]},
#            'tid': 99,
#            'vals': {'colsample_bytree': [0.49],
#                     'gamma': [0.29],
#                     'learning_rate': [0.35000000000000003],
#                     'max_depth': [1],
#                     'min_child_weight': [11.0],
#                     'reg_alpha': [0.8],
#                     'reg_lambda': [0.19],
#                     'subsample': [0.23]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 6, 6, 23, 36, 30, 379000),
#   'result': {'loss': 0.01472075, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 99,
#   'version': 0}]
