# %% [markdown]
# # Example 02: General Use of XGBoostClassifierHyperOpt
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/slickml/slick-ml/blob/master/examples/optimization/example_02_XGBoostClassifierHyperOpt.ipynb)

# %% [markdown]
# ### Google Colab Configuration

# %%
# !git clone https://github.com/slickml/slick-ml.git
# %cd slick-ml
# !pip install -r requirements.txt

# %% [markdown]
# ### Local Environment Configuration

# %%
# # Change path to project root
# %cd ../..
# Out:
# /Users/atahmassebi/Desktop/AmirStuff/GitHub/slick-ml

# %% [markdown]
# ### Import Python Libraries

# %%
# %load_ext autoreload

# widen the screen
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:95% !important; }</style>"))

# change the path and loading class
import os, sys
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# %autoreload
from slickml.optimization import XGBoostClassifierHyperOpt
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ----
# # XGBoostClassifierHyperOpt Docstring

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X = data.data
y = data.target

# %%
import xgboost as xgb

cvr = xgb.cv(
    params={
        "objective": "binary:logistic",
    },
    dtrain=xgb.DMatrix(
        data=X,
        label=y,
    ),
    nfold=4,
    stratified=True,
    metrics="auc",
    early_stopping_rounds=20,
    seed=1367,
    shuffle=True,
)

# %%
cvr.iloc[-1:, 0]
# Out:
# 9    0.999982
# Name: train-auc-mean, dtype: float64

# %%
cvr.tail(2)
# Out:
#    train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 8        0.999930       0.000095       0.989341      0.004216
# 9        0.999982       0.000030       0.988919      0.004086

# %%
cvr.iloc[-1][2]
# Out:
# 0.9889189221020893

# %%
# define X, y
y = df.CLASS.values
X = df.drop(["CLASS"], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=True, stratify=y, random_state=1367
)

# %%
# define the parameters' bounds

from hyperopt import hp


def get_xgb_params():
    """Define Parameter Space"""
    params = {
        "nthread": 4,
        "booster": "gbtree",
        "tree_method": "hist",
        "objective": "binary:logistic",
        "max_depth": hp.choice("max_depth", range(2, 7)),
        "learning_rate": hp.quniform("learning_rate", 0.01, 0.50, 0.01),
        "gamma": hp.quniform("gamma", 0, 0.50, 0.01),
        "min_child_weight": hp.quniform("min_child_weight", 1, 10, 1),
        "subsample": hp.quniform("subsample", 0.1, 1, 0.01),
        "colsample_bytree": hp.quniform("colsample_bytree", 0.1, 1.0, 0.01),
        "gamma": hp.quniform("gamma", 0.0, 1.0, 0.01),
        "reg_alpha": hp.quniform("reg_alpha", 0.0, 1.0, 0.01),
        "reg_lambda": hp.quniform("reg_lambda", 0.0, 1.0, 0.01),
    }

    return params

# %%
# define the parameters' bounds

from hyperopt import hp
from hyperopt.pyll.stochastic import sample


params = {
    "nthread": 4,
    "booster": "gbtree",
    "tree_method": "hist",
    "objective": "binary:logistic",
    "max_depth": [2, 3, 4, 5],
}

# %%
p = sample(params)
p
# Out:
# {'booster': 'gbtree',
#  'max_depth': (2, 3, 4, 5),
#  'nthread': 4,
#  'objective': 'binary:logistic',
#  'tree_method': 'hist'}

# %%
p.update({"x": "foo"})

# %%
p
# Out:
# {'booster': 'gbtree',
#  'max_depth': 6,
#  'nthread': 4,
#  'objective': 'binary:logistic',
#  'tree_method': 'hist',
#  'x': 'foo'}

# %%
# initialize XGBoostClassifierHyperOpt
xho = XGBoostClassifierHyperOpt(
    num_boost_round=200,
    metrics="logloss",
    n_splits=3,
    shuffle=True,
    early_stopping_rounds=20,
    func_name="xgb_cv",
    space=get_xgb_params(),
    max_evals=100,
    verbose=False,
)
# fit
xho.fit(X_train, y_train)
# Out:
# 100%|████████████████| 100/100 [00:08<00:00, 11.75trial/s, best loss: 0.16043033333333334]

# %% [markdown]
# ### Best set of parameters from all runs

# %%
xho.get_optimization_results()
# Out:
#    colsample_bytree  gamma  learning_rate  max_depth  min_child_weight  \
# 0              0.74   0.21           0.31          4               7.0
#
#    reg_alpha  reg_lambda  subsample
# 0       0.85        0.62        0.5

# %% [markdown]
# ### Results from each trial

# %%
import pprint

pprint.pprint(xho.get_optimization_trials().trials)
# Out:
# [{'book_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 512000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [0],
#                     'gamma': [0],
#                     'learning_rate': [0],
#                     'max_depth': [0],
#                     'min_child_weight': [0],
#                     'reg_alpha': [0],
#                     'reg_lambda': [0],
#                     'subsample': [0]},
#            'tid': 0,
#            'vals': {'colsample_bytree': [0.78],
#                     'gamma': [0.66],
#                     'learning_rate': [0.22],
#                     'max_depth': [2],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.43],
#                     'reg_lambda': [0.29],
#                     'subsample': [0.47000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 566000),
#   'result': {'loss': 0.23769966666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 0,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 570000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [1],
#                     'gamma': [1],
#                     'learning_rate': [1],
#                     'max_depth': [1],
#                     'min_child_weight': [1],
#                     'reg_alpha': [1],
#                     'reg_lambda': [1],
#                     'subsample': [1]},
#            'tid': 1,
#            'vals': {'colsample_bytree': [0.75],
#                     'gamma': [0.74],
#                     'learning_rate': [0.24],
#                     'max_depth': [0],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.31],
#                     'reg_lambda': [0.23],
#                     'subsample': [0.58]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 612000),
#   'result': {'loss': 0.2758946666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 1,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 616000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [2],
#                     'gamma': [2],
#                     'learning_rate': [2],
#                     'max_depth': [2],
#                     'min_child_weight': [2],
#                     'reg_alpha': [2],
#                     'reg_lambda': [2],
#                     'subsample': [2]},
#            'tid': 2,
#            'vals': {'colsample_bytree': [0.78],
#                     'gamma': [0.22],
#                     'learning_rate': [0.4],
#                     'max_depth': [4],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.37],
#                     'reg_lambda': [0.93],
#                     'subsample': [0.19]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 745000),
#   'result': {'loss': 0.17207566666666665, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 2,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 747000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [3],
#                     'gamma': [3],
#                     'learning_rate': [3],
#                     'max_depth': [3],
#                     'min_child_weight': [3],
#                     'reg_alpha': [3],
#                     'reg_lambda': [3],
#                     'subsample': [3]},
#            'tid': 3,
#            'vals': {'colsample_bytree': [0.12],
#                     'gamma': [0.27],
#                     'learning_rate': [0.04],
#                     'max_depth': [2],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.34],
#                     'reg_lambda': [0.9400000000000001],
#                     'subsample': [0.35000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 772000),
#   'result': {'loss': 0.351059, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 3,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 776000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [4],
#                     'gamma': [4],
#                     'learning_rate': [4],
#                     'max_depth': [4],
#                     'min_child_weight': [4],
#                     'reg_alpha': [4],
#                     'reg_lambda': [4],
#                     'subsample': [4]},
#            'tid': 4,
#            'vals': {'colsample_bytree': [0.9],
#                     'gamma': [0.21],
#                     'learning_rate': [0.15],
#                     'max_depth': [0],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.31],
#                     'reg_lambda': [0.0],
#                     'subsample': [0.39]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 865000),
#   'result': {'loss': 0.27997099999999997, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 4,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 867000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [5],
#                     'gamma': [5],
#                     'learning_rate': [5],
#                     'max_depth': [5],
#                     'min_child_weight': [5],
#                     'reg_alpha': [5],
#                     'reg_lambda': [5],
#                     'subsample': [5]},
#            'tid': 5,
#            'vals': {'colsample_bytree': [0.51],
#                     'gamma': [0.93],
#                     'learning_rate': [0.36],
#                     'max_depth': [3],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.6],
#                     'reg_lambda': [0.87],
#                     'subsample': [0.11]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 990000),
#   'result': {'loss': 0.46781466666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 5,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 16, 994000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [6],
#                     'gamma': [6],
#                     'learning_rate': [6],
#                     'max_depth': [6],
#                     'min_child_weight': [6],
#                     'reg_alpha': [6],
#                     'reg_lambda': [6],
#                     'subsample': [6]},
#            'tid': 6,
#            'vals': {'colsample_bytree': [0.9],
#                     'gamma': [0.32],
#                     'learning_rate': [0.32],
#                     'max_depth': [4],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.55],
#                     'reg_lambda': [0.58],
#                     'subsample': [0.81]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 56000),
#   'result': {'loss': 0.28636599999999995, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 6,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 59000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [7],
#                     'gamma': [7],
#                     'learning_rate': [7],
#                     'max_depth': [7],
#                     'min_child_weight': [7],
#                     'reg_alpha': [7],
#                     'reg_lambda': [7],
#                     'subsample': [7]},
#            'tid': 7,
#            'vals': {'colsample_bytree': [0.13],
#                     'gamma': [0.46],
#                     'learning_rate': [0.31],
#                     'max_depth': [4],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.84],
#                     'reg_lambda': [0.64],
#                     'subsample': [0.44]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 112000),
#   'result': {'loss': 0.20481366666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 7,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 116000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [8],
#                     'gamma': [8],
#                     'learning_rate': [8],
#                     'max_depth': [8],
#                     'min_child_weight': [8],
#                     'reg_alpha': [8],
#                     'reg_lambda': [8],
#                     'subsample': [8]},
#            'tid': 8,
#            'vals': {'colsample_bytree': [0.89],
#                     'gamma': [0.53],
#                     'learning_rate': [0.29],
#                     'max_depth': [4],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.1],
#                     'reg_lambda': [0.25],
#                     'subsample': [0.34]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 148000),
#   'result': {'loss': 0.436745, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 8,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 151000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [9],
#                     'gamma': [9],
#                     'learning_rate': [9],
#                     'max_depth': [9],
#                     'min_child_weight': [9],
#                     'reg_alpha': [9],
#                     'reg_lambda': [9],
#                     'subsample': [9]},
#            'tid': 9,
#            'vals': {'colsample_bytree': [0.22],
#                     'gamma': [0.6900000000000001],
#                     'learning_rate': [0.47000000000000003],
#                     'max_depth': [4],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.15],
#                     'reg_lambda': [0.4],
#                     'subsample': [0.74]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 218000),
#   'result': {'loss': 0.255833, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 9,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 221000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [10],
#                     'gamma': [10],
#                     'learning_rate': [10],
#                     'max_depth': [10],
#                     'min_child_weight': [10],
#                     'reg_alpha': [10],
#                     'reg_lambda': [10],
#                     'subsample': [10]},
#            'tid': 10,
#            'vals': {'colsample_bytree': [0.23],
#                     'gamma': [0.44],
#                     'learning_rate': [0.03],
#                     'max_depth': [3],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.65],
#                     'reg_lambda': [0.58],
#                     'subsample': [0.73]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 280000),
#   'result': {'loss': 0.37976933333333335, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 10,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 283000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [11],
#                     'gamma': [11],
#                     'learning_rate': [11],
#                     'max_depth': [11],
#                     'min_child_weight': [11],
#                     'reg_alpha': [11],
#                     'reg_lambda': [11],
#                     'subsample': [11]},
#            'tid': 11,
#            'vals': {'colsample_bytree': [0.89],
#                     'gamma': [0.62],
#                     'learning_rate': [0.4],
#                     'max_depth': [4],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.15],
#                     'reg_lambda': [0.98],
#                     'subsample': [0.44]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 311000),
#   'result': {'loss': 0.281547, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 11,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 314000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [12],
#                     'gamma': [12],
#                     'learning_rate': [12],
#                     'max_depth': [12],
#                     'min_child_weight': [12],
#                     'reg_alpha': [12],
#                     'reg_lambda': [12],
#                     'subsample': [12]},
#            'tid': 12,
#            'vals': {'colsample_bytree': [0.23],
#                     'gamma': [0.05],
#                     'learning_rate': [0.11],
#                     'max_depth': [0],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.81],
#                     'reg_lambda': [0.49],
#                     'subsample': [0.2]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 341000),
#   'result': {'loss': 0.32609333333333335, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 12,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 344000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [13],
#                     'gamma': [13],
#                     'learning_rate': [13],
#                     'max_depth': [13],
#                     'min_child_weight': [13],
#                     'reg_alpha': [13],
#                     'reg_lambda': [13],
#                     'subsample': [13]},
#            'tid': 13,
#            'vals': {'colsample_bytree': [0.22],
#                     'gamma': [0.99],
#                     'learning_rate': [0.02],
#                     'max_depth': [4],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.8300000000000001],
#                     'reg_lambda': [0.13],
#                     'subsample': [0.34]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 404000),
#   'result': {'loss': 0.37016333333333334, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 13,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 406000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [14],
#                     'gamma': [14],
#                     'learning_rate': [14],
#                     'max_depth': [14],
#                     'min_child_weight': [14],
#                     'reg_alpha': [14],
#                     'reg_lambda': [14],
#                     'subsample': [14]},
#            'tid': 14,
#            'vals': {'colsample_bytree': [0.45],
#                     'gamma': [0.18],
#                     'learning_rate': [0.03],
#                     'max_depth': [3],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.09],
#                     'reg_lambda': [0.54],
#                     'subsample': [0.13]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 437000),
#   'result': {'loss': 0.33528933333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 14,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 440000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [15],
#                     'gamma': [15],
#                     'learning_rate': [15],
#                     'max_depth': [15],
#                     'min_child_weight': [15],
#                     'reg_alpha': [15],
#                     'reg_lambda': [15],
#                     'subsample': [15]},
#            'tid': 15,
#            'vals': {'colsample_bytree': [0.35000000000000003],
#                     'gamma': [0.23],
#                     'learning_rate': [0.31],
#                     'max_depth': [0],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.44],
#                     'reg_lambda': [0.09],
#                     'subsample': [0.84]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 574000),
#   'result': {'loss': 0.28984666666666664, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 15,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 578000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [16],
#                     'gamma': [16],
#                     'learning_rate': [16],
#                     'max_depth': [16],
#                     'min_child_weight': [16],
#                     'reg_alpha': [16],
#                     'reg_lambda': [16],
#                     'subsample': [16]},
#            'tid': 16,
#            'vals': {'colsample_bytree': [0.49],
#                     'gamma': [0.27],
#                     'learning_rate': [0.27],
#                     'max_depth': [1],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.66],
#                     'reg_lambda': [0.9500000000000001],
#                     'subsample': [0.11]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 656000),
#   'result': {'loss': 0.32672066666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 16,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 658000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [17],
#                     'gamma': [17],
#                     'learning_rate': [17],
#                     'max_depth': [17],
#                     'min_child_weight': [17],
#                     'reg_alpha': [17],
#                     'reg_lambda': [17],
#                     'subsample': [17]},
#            'tid': 17,
#            'vals': {'colsample_bytree': [0.52],
#                     'gamma': [0.6900000000000001],
#                     'learning_rate': [0.06],
#                     'max_depth': [4],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.13],
#                     'reg_lambda': [0.39],
#                     'subsample': [0.14]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 724000),
#   'result': {'loss': 0.2389146666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 17,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 728000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [18],
#                     'gamma': [18],
#                     'learning_rate': [18],
#                     'max_depth': [18],
#                     'min_child_weight': [18],
#                     'reg_alpha': [18],
#                     'reg_lambda': [18],
#                     'subsample': [18]},
#            'tid': 18,
#            'vals': {'colsample_bytree': [0.86],
#                     'gamma': [0.9400000000000001],
#                     'learning_rate': [0.22],
#                     'max_depth': [3],
#                     'min_child_weight': [1.0],
#                     'reg_alpha': [0.79],
#                     'reg_lambda': [0.61],
#                     'subsample': [0.75]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 846000),
#   'result': {'loss': 0.320347, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 18,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 848000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [19],
#                     'gamma': [19],
#                     'learning_rate': [19],
#                     'max_depth': [19],
#                     'min_child_weight': [19],
#                     'reg_alpha': [19],
#                     'reg_lambda': [19],
#                     'subsample': [19]},
#            'tid': 19,
#            'vals': {'colsample_bytree': [0.8200000000000001],
#                     'gamma': [1.0],
#                     'learning_rate': [0.46],
#                     'max_depth': [3],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.64],
#                     'reg_lambda': [0.25],
#                     'subsample': [0.16]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 880000),
#   'result': {'loss': 0.3134616666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 19,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 901000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [20],
#                     'gamma': [20],
#                     'learning_rate': [20],
#                     'max_depth': [20],
#                     'min_child_weight': [20],
#                     'reg_alpha': [20],
#                     'reg_lambda': [20],
#                     'subsample': [20]},
#            'tid': 20,
#            'vals': {'colsample_bytree': [0.66],
#                     'gamma': [0.02],
#                     'learning_rate': [0.4],
#                     'max_depth': [1],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.9500000000000001],
#                     'reg_lambda': [0.74],
#                     'subsample': [0.25]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 928000),
#   'result': {'loss': 0.24326033333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 20,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 946000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [21],
#                     'gamma': [21],
#                     'learning_rate': [21],
#                     'max_depth': [21],
#                     'min_child_weight': [21],
#                     'reg_alpha': [21],
#                     'reg_lambda': [21],
#                     'subsample': [21]},
#            'tid': 21,
#            'vals': {'colsample_bytree': [0.63],
#                     'gamma': [0.4],
#                     'learning_rate': [0.42],
#                     'max_depth': [4],
#                     'min_child_weight': [3.0],
#                     'reg_alpha': [0.97],
#                     'reg_lambda': [0.76],
#                     'subsample': [0.59]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 17, 982000),
#   'result': {'loss': 0.3792003333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 21,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 1000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [22],
#                     'gamma': [22],
#                     'learning_rate': [22],
#                     'max_depth': [22],
#                     'min_child_weight': [22],
#                     'reg_alpha': [22],
#                     'reg_lambda': [22],
#                     'subsample': [22]},
#            'tid': 22,
#            'vals': {'colsample_bytree': [0.99],
#                     'gamma': [0.12],
#                     'learning_rate': [0.34],
#                     'max_depth': [4],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.25],
#                     'reg_lambda': [0.71],
#                     'subsample': [0.25]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 37000),
#   'result': {'loss': 0.2507483333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 22,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 52000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [23],
#                     'gamma': [23],
#                     'learning_rate': [23],
#                     'max_depth': [23],
#                     'min_child_weight': [23],
#                     'reg_alpha': [23],
#                     'reg_lambda': [23],
#                     'subsample': [23]},
#            'tid': 23,
#            'vals': {'colsample_bytree': [0.68],
#                     'gamma': [0.53],
#                     'learning_rate': [0.5],
#                     'max_depth': [4],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.5],
#                     'reg_lambda': [0.84],
#                     'subsample': [0.97]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 140000),
#   'result': {'loss': 0.29701266666666665, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 23,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 162000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [24],
#                     'gamma': [24],
#                     'learning_rate': [24],
#                     'max_depth': [24],
#                     'min_child_weight': [24],
#                     'reg_alpha': [24],
#                     'reg_lambda': [24],
#                     'subsample': [24]},
#            'tid': 24,
#            'vals': {'colsample_bytree': [0.4],
#                     'gamma': [0.36],
#                     'learning_rate': [0.17],
#                     'max_depth': [2],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.0],
#                     'reg_lambda': [0.65],
#                     'subsample': [0.51]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 260000),
#   'result': {'loss': 0.42036866666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 24,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 275000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [25],
#                     'gamma': [25],
#                     'learning_rate': [25],
#                     'max_depth': [25],
#                     'min_child_weight': [25],
#                     'reg_alpha': [25],
#                     'reg_lambda': [25],
#                     'subsample': [25]},
#            'tid': 25,
#            'vals': {'colsample_bytree': [0.99],
#                     'gamma': [0.8200000000000001],
#                     'learning_rate': [0.36],
#                     'max_depth': [1],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.87],
#                     'reg_lambda': [0.84],
#                     'subsample': [0.63]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 316000),
#   'result': {'loss': 0.47641833333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 25,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 338000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [26],
#                     'gamma': [26],
#                     'learning_rate': [26],
#                     'max_depth': [26],
#                     'min_child_weight': [26],
#                     'reg_alpha': [26],
#                     'reg_lambda': [26],
#                     'subsample': [26]},
#            'tid': 26,
#            'vals': {'colsample_bytree': [0.58],
#                     'gamma': [0.46],
#                     'learning_rate': [0.45],
#                     'max_depth': [4],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.42],
#                     'reg_lambda': [0.45],
#                     'subsample': [0.26]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 427000),
#   'result': {'loss': 0.29903233333333334, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 26,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 443000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [27],
#                     'gamma': [27],
#                     'learning_rate': [27],
#                     'max_depth': [27],
#                     'min_child_weight': [27],
#                     'reg_alpha': [27],
#                     'reg_lambda': [27],
#                     'subsample': [27]},
#            'tid': 27,
#            'vals': {'colsample_bytree': [0.73],
#                     'gamma': [0.1],
#                     'learning_rate': [0.37],
#                     'max_depth': [4],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.74],
#                     'reg_lambda': [0.6900000000000001],
#                     'subsample': [0.65]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 615000),
#   'result': {'loss': 0.20228366666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 27,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 637000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [28],
#                     'gamma': [28],
#                     'learning_rate': [28],
#                     'max_depth': [28],
#                     'min_child_weight': [28],
#                     'reg_alpha': [28],
#                     'reg_lambda': [28],
#                     'subsample': [28]},
#            'tid': 28,
#            'vals': {'colsample_bytree': [0.75],
#                     'gamma': [0.1],
#                     'learning_rate': [0.38],
#                     'max_depth': [2],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.75],
#                     'reg_lambda': [0.8],
#                     'subsample': [1.0]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 686000),
#   'result': {'loss': 0.25560466666666665, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 28,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 703000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [29],
#                     'gamma': [29],
#                     'learning_rate': [29],
#                     'max_depth': [29],
#                     'min_child_weight': [29],
#                     'reg_alpha': [29],
#                     'reg_lambda': [29],
#                     'subsample': [29]},
#            'tid': 29,
#            'vals': {'colsample_bytree': [0.72],
#                     'gamma': [0.14],
#                     'learning_rate': [0.49],
#                     'max_depth': [4],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.72],
#                     'reg_lambda': [1.0],
#                     'subsample': [0.65]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 760000),
#   'result': {'loss': 0.27160866666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 29,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 780000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [30],
#                     'gamma': [30],
#                     'learning_rate': [30],
#                     'max_depth': [30],
#                     'min_child_weight': [30],
#                     'reg_alpha': [30],
#                     'reg_lambda': [30],
#                     'subsample': [30]},
#            'tid': 30,
#            'vals': {'colsample_bytree': [0.59],
#                     'gamma': [0.01],
#                     'learning_rate': [0.43],
#                     'max_depth': [1],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.38],
#                     'reg_lambda': [0.9],
#                     'subsample': [0.92]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 817000),
#   'result': {'loss': 0.2578766666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 30,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 836000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [31],
#                     'gamma': [31],
#                     'learning_rate': [31],
#                     'max_depth': [31],
#                     'min_child_weight': [31],
#                     'reg_alpha': [31],
#                     'reg_lambda': [31],
#                     'subsample': [31]},
#            'tid': 31,
#            'vals': {'colsample_bytree': [0.77],
#                     'gamma': [0.07],
#                     'learning_rate': [0.28],
#                     'max_depth': [2],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.22],
#                     'reg_lambda': [0.68],
#                     'subsample': [0.5]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 864000),
#   'result': {'loss': 0.4768046666666666, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 31,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 884000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [32],
#                     'gamma': [32],
#                     'learning_rate': [32],
#                     'max_depth': [32],
#                     'min_child_weight': [32],
#                     'reg_alpha': [32],
#                     'reg_lambda': [32],
#                     'subsample': [32]},
#            'tid': 32,
#            'vals': {'colsample_bytree': [0.8200000000000001],
#                     'gamma': [0.29],
#                     'learning_rate': [0.24],
#                     'max_depth': [0],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.92],
#                     'reg_lambda': [0.77],
#                     'subsample': [0.6900000000000001]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 925000),
#   'result': {'loss': 0.270921, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 32,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 942000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [33],
#                     'gamma': [33],
#                     'learning_rate': [33],
#                     'max_depth': [33],
#                     'min_child_weight': [33],
#                     'reg_alpha': [33],
#                     'reg_lambda': [33],
#                     'subsample': [33]},
#            'tid': 33,
#            'vals': {'colsample_bytree': [0.9500000000000001],
#                     'gamma': [0.17],
#                     'learning_rate': [0.18],
#                     'max_depth': [4],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.53],
#                     'reg_lambda': [0.93],
#                     'subsample': [0.55]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 18, 979000),
#   'result': {'loss': 0.2536306666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 33,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [34],
#                     'gamma': [34],
#                     'learning_rate': [34],
#                     'max_depth': [34],
#                     'min_child_weight': [34],
#                     'reg_alpha': [34],
#                     'reg_lambda': [34],
#                     'subsample': [34]},
#            'tid': 34,
#            'vals': {'colsample_bytree': [0.71],
#                     'gamma': [0.6],
#                     'learning_rate': [0.34],
#                     'max_depth': [2],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.46],
#                     'reg_lambda': [0.81],
#                     'subsample': [0.85]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 75000),
#   'result': {'loss': 0.2739133333333334, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 34,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 92000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [35],
#                     'gamma': [35],
#                     'learning_rate': [35],
#                     'max_depth': [35],
#                     'min_child_weight': [35],
#                     'reg_alpha': [35],
#                     'reg_lambda': [35],
#                     'subsample': [35]},
#            'tid': 35,
#            'vals': {'colsample_bytree': [0.8300000000000001],
#                     'gamma': [0.23],
#                     'learning_rate': [0.22],
#                     'max_depth': [4],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.5700000000000001],
#                     'reg_lambda': [0.32],
#                     'subsample': [0.41000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 125000),
#   'result': {'loss': 0.37191966666666665, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 35,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 149000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [36],
#                     'gamma': [36],
#                     'learning_rate': [36],
#                     'max_depth': [36],
#                     'min_child_weight': [36],
#                     'reg_alpha': [36],
#                     'reg_lambda': [36],
#                     'subsample': [36]},
#            'tid': 36,
#            'vals': {'colsample_bytree': [0.9500000000000001],
#                     'gamma': [0.36],
#                     'learning_rate': [0.4],
#                     'max_depth': [0],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.28],
#                     'reg_lambda': [0.87],
#                     'subsample': [0.59]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 173000),
#   'result': {'loss': 0.47225933333333336, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 36,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 193000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [37],
#                     'gamma': [37],
#                     'learning_rate': [37],
#                     'max_depth': [37],
#                     'min_child_weight': [37],
#                     'reg_alpha': [37],
#                     'reg_lambda': [37],
#                     'subsample': [37]},
#            'tid': 37,
#            'vals': {'colsample_bytree': [0.63],
#                     'gamma': [0.0],
#                     'learning_rate': [0.37],
#                     'max_depth': [4],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.35000000000000003],
#                     'reg_lambda': [0.52],
#                     'subsample': [0.79]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 250000),
#   'result': {'loss': 0.24108433333333332, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 37,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 272000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [38],
#                     'gamma': [38],
#                     'learning_rate': [38],
#                     'max_depth': [38],
#                     'min_child_weight': [38],
#                     'reg_alpha': [38],
#                     'reg_lambda': [38],
#                     'subsample': [38]},
#            'tid': 38,
#            'vals': {'colsample_bytree': [0.8],
#                     'gamma': [0.33],
#                     'learning_rate': [0.44],
#                     'max_depth': [4],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.71],
#                     'reg_lambda': [0.68],
#                     'subsample': [0.37]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 414000),
#   'result': {'loss': 0.341373, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 38,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 432000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [39],
#                     'gamma': [39],
#                     'learning_rate': [39],
#                     'max_depth': [39],
#                     'min_child_weight': [39],
#                     'reg_alpha': [39],
#                     'reg_lambda': [39],
#                     'subsample': [39]},
#            'tid': 39,
#            'vals': {'colsample_bytree': [0.33],
#                     'gamma': [0.21],
#                     'learning_rate': [0.48],
#                     'max_depth': [1],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.6],
#                     'reg_lambda': [0.9],
#                     'subsample': [0.89]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 457000),
#   'result': {'loss': 0.365907, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 39,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 483000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [40],
#                     'gamma': [40],
#                     'learning_rate': [40],
#                     'max_depth': [40],
#                     'min_child_weight': [40],
#                     'reg_alpha': [40],
#                     'reg_lambda': [40],
#                     'subsample': [40]},
#            'tid': 40,
#            'vals': {'colsample_bytree': [0.55],
#                     'gamma': [0.07],
#                     'learning_rate': [0.33],
#                     'max_depth': [4],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.39],
#                     'reg_lambda': [0.6],
#                     'subsample': [0.68]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 579000),
#   'result': {'loss': 0.3085773333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 40,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 598000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [41],
#                     'gamma': [41],
#                     'learning_rate': [41],
#                     'max_depth': [41],
#                     'min_child_weight': [41],
#                     'reg_alpha': [41],
#                     'reg_lambda': [41],
#                     'subsample': [41]},
#            'tid': 41,
#            'vals': {'colsample_bytree': [0.72],
#                     'gamma': [0.77],
#                     'learning_rate': [0.3],
#                     'max_depth': [3],
#                     'min_child_weight': [2.0],
#                     'reg_alpha': [0.01],
#                     'reg_lambda': [0.98],
#                     'subsample': [0.3]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 620000),
#   'result': {'loss': 0.32450666666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 41,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 647000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [42],
#                     'gamma': [42],
#                     'learning_rate': [42],
#                     'max_depth': [42],
#                     'min_child_weight': [42],
#                     'reg_alpha': [42],
#                     'reg_lambda': [42],
#                     'subsample': [42]},
#            'tid': 42,
#            'vals': {'colsample_bytree': [0.9500000000000001],
#                     'gamma': [0.55],
#                     'learning_rate': [0.26],
#                     'max_depth': [0],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.88],
#                     'reg_lambda': [0.41000000000000003],
#                     'subsample': [0.47000000000000003]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 678000),
#   'result': {'loss': 0.3399703333333333, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 42,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 697000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [43],
#                     'gamma': [43],
#                     'learning_rate': [43],
#                     'max_depth': [43],
#                     'min_child_weight': [43],
#                     'reg_alpha': [43],
#                     'reg_lambda': [43],
#                     'subsample': [43]},
#            'tid': 43,
#            'vals': {'colsample_bytree': [0.45],
#                     'gamma': [0.43],
#                     'learning_rate': [0.42],
#                     'max_depth': [4],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.49],
#                     'reg_lambda': [0.55],
#                     'subsample': [0.18]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 737000),
#   'result': {'loss': 0.3773576666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 43,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 19, 761000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [44],
#                     'gamma': [44],
#                     'learning_rate': [44],
#                     'max_depth': [44],
#                     'min_child_weight': [44],
#                     'reg_alpha': [44],
#                     'reg_lambda': [44],
#                     'subsample': [44]},
#            'tid': 44,
#            'vals': {'colsample_bytree': [0.85],
#                     'gamma': [0.17],
#                     'learning_rate': [0.39],
#                     'max_depth': [2],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.23],
#                     'reg_lambda': [0.32],
#                     'subsample': [0.55]},
#            'workdir': None},
#   'owner': None,
# ...
#            'idxs': {'colsample_bytree': [85],
#                     'gamma': [85],
#                     'learning_rate': [85],
#                     'max_depth': [85],
#                     'min_child_weight': [85],
#                     'reg_alpha': [85],
#                     'reg_lambda': [85],
#                     'subsample': [85]},
#            'tid': 85,
#            'vals': {'colsample_bytree': [0.78],
#                     'gamma': [0.16],
#                     'learning_rate': [0.3],
#                     'max_depth': [1],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.9400000000000001],
#                     'reg_lambda': [0.47000000000000003],
#                     'subsample': [0.38]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 23, 717000),
#   'result': {'loss': 0.36708300000000005, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 85,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 23, 743000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [86],
#                     'gamma': [86],
#                     'learning_rate': [86],
#                     'max_depth': [86],
#                     'min_child_weight': [86],
#                     'reg_alpha': [86],
#                     'reg_lambda': [86],
#                     'subsample': [86]},
#            'tid': 86,
#            'vals': {'colsample_bytree': [0.6],
#                     'gamma': [0.37],
#                     'learning_rate': [0.33],
#                     'max_depth': [0],
#                     'min_child_weight': [5.0],
#                     'reg_alpha': [0.16],
#                     'reg_lambda': [0.8300000000000001],
#                     'subsample': [0.33]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 23, 805000),
#   'result': {'loss': 0.24125200000000002, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 86,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 23, 835000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [87],
#                     'gamma': [87],
#                     'learning_rate': [87],
#                     'max_depth': [87],
#                     'min_child_weight': [87],
#                     'reg_alpha': [87],
#                     'reg_lambda': [87],
#                     'subsample': [87]},
#            'tid': 87,
#            'vals': {'colsample_bytree': [0.68],
#                     'gamma': [0.33],
#                     'learning_rate': [0.35000000000000003],
#                     'max_depth': [4],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.43],
#                     'reg_lambda': [0.75],
#                     'subsample': [0.6]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 23, 948000),
#   'result': {'loss': 0.37820733333333334, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 87,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 23, 975000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [88],
#                     'gamma': [88],
#                     'learning_rate': [88],
#                     'max_depth': [88],
#                     'min_child_weight': [88],
#                     'reg_alpha': [88],
#                     'reg_lambda': [88],
#                     'subsample': [88]},
#            'tid': 88,
#            'vals': {'colsample_bytree': [0.84],
#                     'gamma': [0.03],
#                     'learning_rate': [0.45],
#                     'max_depth': [3],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.77],
#                     'reg_lambda': [0.66],
#                     'subsample': [0.71]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 89000),
#   'result': {'loss': 0.39110566666666663, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 88,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 120000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [89],
#                     'gamma': [89],
#                     'learning_rate': [89],
#                     'max_depth': [89],
#                     'min_child_weight': [89],
#                     'reg_alpha': [89],
#                     'reg_lambda': [89],
#                     'subsample': [89]},
#            'tid': 89,
#            'vals': {'colsample_bytree': [0.45],
#                     'gamma': [0.06],
#                     'learning_rate': [0.41000000000000003],
#                     'max_depth': [4],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.3],
#                     'reg_lambda': [0.79],
#                     'subsample': [0.87]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 168000),
#   'result': {'loss': 0.28463933333333336, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 89,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 194000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [90],
#                     'gamma': [90],
#                     'learning_rate': [90],
#                     'max_depth': [90],
#                     'min_child_weight': [90],
#                     'reg_alpha': [90],
#                     'reg_lambda': [90],
#                     'subsample': [90]},
#            'tid': 90,
#            'vals': {'colsample_bytree': [0.9],
#                     'gamma': [0.52],
#                     'learning_rate': [0.25],
#                     'max_depth': [2],
#                     'min_child_weight': [6.0],
#                     'reg_alpha': [0.62],
#                     'reg_lambda': [0.66],
#                     'subsample': [1.0]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 229000),
#   'result': {'loss': 0.24860833333333332, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 90,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 258000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [91],
#                     'gamma': [91],
#                     'learning_rate': [91],
#                     'max_depth': [91],
#                     'min_child_weight': [91],
#                     'reg_alpha': [91],
#                     'reg_lambda': [91],
#                     'subsample': [91]},
#            'tid': 91,
#            'vals': {'colsample_bytree': [0.97],
#                     'gamma': [0.21],
#                     'learning_rate': [0.27],
#                     'max_depth': [4],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.04],
#                     'reg_lambda': [0.25],
#                     'subsample': [0.24]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 301000),
#   'result': {'loss': 0.24913600000000002, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 91,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 328000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [92],
#                     'gamma': [92],
#                     'learning_rate': [92],
#                     'max_depth': [92],
#                     'min_child_weight': [92],
#                     'reg_alpha': [92],
#                     'reg_lambda': [92],
#                     'subsample': [92]},
#            'tid': 92,
#            'vals': {'colsample_bytree': [0.71],
#                     'gamma': [0.19],
#                     'learning_rate': [0.1],
#                     'max_depth': [1],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.47000000000000003],
#                     'reg_lambda': [0.54],
#                     'subsample': [0.48]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 380000),
#   'result': {'loss': 0.353256, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 92,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 411000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [93],
#                     'gamma': [93],
#                     'learning_rate': [93],
#                     'max_depth': [93],
#                     'min_child_weight': [93],
#                     'reg_alpha': [93],
#                     'reg_lambda': [93],
#                     'subsample': [93]},
#            'tid': 93,
#            'vals': {'colsample_bytree': [0.53],
#                     'gamma': [0.67],
#                     'learning_rate': [0.38],
#                     'max_depth': [4],
#                     'min_child_weight': [4.0],
#                     'reg_alpha': [0.41000000000000003],
#                     'reg_lambda': [0.86],
#                     'subsample': [0.18]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 437000),
#   'result': {'loss': 0.32097233333333336, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 93,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 464000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [94],
#                     'gamma': [94],
#                     'learning_rate': [94],
#                     'max_depth': [94],
#                     'min_child_weight': [94],
#                     'reg_alpha': [94],
#                     'reg_lambda': [94],
#                     'subsample': [94]},
#            'tid': 94,
#            'vals': {'colsample_bytree': [0.76],
#                     'gamma': [0.97],
#                     'learning_rate': [0.36],
#                     'max_depth': [0],
#                     'min_child_weight': [7.0],
#                     'reg_alpha': [0.86],
#                     'reg_lambda': [0.89],
#                     'subsample': [0.68]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 556000),
#   'result': {'loss': 0.29767, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 94,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 588000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [95],
#                     'gamma': [95],
#                     'learning_rate': [95],
#                     'max_depth': [95],
#                     'min_child_weight': [95],
#                     'reg_alpha': [95],
#                     'reg_lambda': [95],
#                     'subsample': [95]},
#            'tid': 95,
#            'vals': {'colsample_bytree': [0.64],
#                     'gamma': [0.41000000000000003],
#                     'learning_rate': [0.31],
#                     'max_depth': [4],
#                     'min_child_weight': [8.0],
#                     'reg_alpha': [0.96],
#                     'reg_lambda': [0.71],
#                     'subsample': [0.97]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 619000),
#   'result': {'loss': 0.47653966666666664, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 95,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 647000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [96],
#                     'gamma': [96],
#                     'learning_rate': [96],
#                     'max_depth': [96],
#                     'min_child_weight': [96],
#                     'reg_alpha': [96],
#                     'reg_lambda': [96],
#                     'subsample': [96]},
#            'tid': 96,
#            'vals': {'colsample_bytree': [0.48],
#                     'gamma': [0.3],
#                     'learning_rate': [0.42],
#                     'max_depth': [3],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.8],
#                     'reg_lambda': [0.59],
#                     'subsample': [0.63]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 702000),
#   'result': {'loss': 0.173009, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 96,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 733000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [97],
#                     'gamma': [97],
#                     'learning_rate': [97],
#                     'max_depth': [97],
#                     'min_child_weight': [97],
#                     'reg_alpha': [97],
#                     'reg_lambda': [97],
#                     'subsample': [97]},
#            'tid': 97,
#            'vals': {'colsample_bytree': [0.42],
#                     'gamma': [0.45],
#                     'learning_rate': [0.49],
#                     'max_depth': [3],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.8],
#                     'reg_lambda': [0.21],
#                     'subsample': [0.76]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 774000),
#   'result': {'loss': 0.4331426666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 97,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 803000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [98],
#                     'gamma': [98],
#                     'learning_rate': [98],
#                     'max_depth': [98],
#                     'min_child_weight': [98],
#                     'reg_alpha': [98],
#                     'reg_lambda': [98],
#                     'subsample': [98]},
#            'tid': 98,
#            'vals': {'colsample_bytree': [0.35000000000000003],
#                     'gamma': [0.5700000000000001],
#                     'learning_rate': [0.43],
#                     'max_depth': [3],
#                     'min_child_weight': [9.0],
#                     'reg_alpha': [0.56],
#                     'reg_lambda': [0.32],
#                     'subsample': [0.92]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 939000),
#   'result': {'loss': 0.3859086666666667, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 98,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 9, 5, 2, 55, 24, 970000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#            'idxs': {'colsample_bytree': [99],
#                     'gamma': [99],
#                     'learning_rate': [99],
#                     'max_depth': [99],
#                     'min_child_weight': [99],
#                     'reg_alpha': [99],
#                     'reg_lambda': [99],
#                     'subsample': [99]},
#            'tid': 99,
#            'vals': {'colsample_bytree': [0.5],
#                     'gamma': [0.3],
#                     'learning_rate': [0.46],
#                     'max_depth': [3],
#                     'min_child_weight': [10.0],
#                     'reg_alpha': [0.58],
#                     'reg_lambda': [0.59],
#                     'subsample': [0.56]},
#            'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 9, 5, 2, 55, 25, 17000),
#   'result': {'loss': 0.36290200000000006, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 99,
#   'version': 0}]
